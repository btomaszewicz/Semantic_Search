# %% [markdown]
# ## Generate models for the search function

# %% [markdown]
# Dataset from
#
# https://www.kaggle.com/datasets/jrobischon/wikipedia-movie-plots/data

# %% [markdown]
# Code based on
#
# https://www.kaggle.com/code/ajitrajput/semantic-search-engine-using-nlp/notebook

# %%
import numpy as np
import pandas as pd
import spacy
import string
import gensim
import operator
import re

# %%
df_movies = pd.read_csv('../raw_data/wiki_movie_plots_deduped.csv')
df_movies.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      34886 non-null  int64
#  1   Title             34886 non-null  object
#  2   Origin/Ethnicity  34886 non-null  object
#  3   Director          34886 non-null  object
#  4   Cast              33464 non-null  object
#  5   Genre             34886 non-null  object
#  6   Wiki Page         34886 non-null  object
#  7   Plot              34886 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
am_movies = df_movies[df_movies['Origin/Ethnicity'] == 'American']
am_movies = am_movies.reset_index(drop=True)

# %%
#NaNs in am_movies
am_movies.isnull().sum()
# Out:
# Release Year          0
# Title                 0
# Origin/Ethnicity      0
# Director              0
# Cast                317
# Genre                 0
# Wiki Page             0
# Plot                  0
# dtype: int64

# %%
print(f"Number of American movies: {len(am_movies)}")
print(f"Number of all movies: {len(df_movies)}")
# Out:
# Number of American movies: 17377
# Number of all movies: 34886

# %%
#How many genres in American movies?
am_movies['Genre'].nunique()
# Out:
# 771

# %%
American_genres = am_movies['Genre'].unique()
American_genres
# Out:
# array(['unknown', 'western', 'comedy', 'short',
#        'short action/crime western', 'short film', 'biographical',
#        'drama', 'adventure', 'short fantasy', 'silent sports', 'horror',
#        'crime', 'drama, horror', 'historical drama', 'fantasy drama',
#        'biographical drama', 'documentary drama', 'fantasy',
#        'adventure serial', 'epic', 'historical', 'comedy short',
#        'comedy, western', 'biography', 'action adventure',
#        'western drama', 'short comedy', 'comedy–drama', 'romantic drama',
#        'mystery', 'crime drama', 'romance',
#        'sexual hygiene/exploitation film', 'comedy drama', 'war drama',
#        'spy', 'romantic comedy', 'propaganda', 'ww1 propaganda', 'biopic',
#        'animated series', 'drama romance', 'melodrama', 'period drama',
#        'swashbuckler', 'romance drama', 'drama, adventure',
#        'crime comedy', 'documentary', 'comedy western', 'fantasy, family',
#        'war', 'comedy, adventure', 'fantasy, adventure', 'thriller',
#        'dramatic comedy', 'romantic comedy/drama', 'mystery, thriller',
#        'crime thriller', 'american football', 'fantasy, romance',
#        'comedy, horror, mystery', 'semi-staged documentary',
#        'biblical drama', 'race film', 'comedy adventure',
#        'romance, drama', 'comedy, romance', 'crime, drama', 'musical',
#        'musical comedy', 'operetta', 'comedy mystery', 'detective',
#        'romance musical', 'drama, war', 'horror, comedy', 'drama, crime',
#        'musical, comedy', 'costume drama', 'prison drama', 'spy drama',
#        'comedy, drama', 'action', 'drama, western', 'drama, thriller',
#        'horror, science fiction', 'romantic crime/mystery',
#        'drama, musical', 'film noir', 'sports', 'adventure film',
#        'comedy, musical', 'romantic', 'drama, mystery', 'animation',
#        'science fiction', 'comedy, crime', 'drama, sports',
#        'horror, sci-fi', 'adventure, thriller', 'crime, horror',
#        'comedy, horror', 'adventure, drama', 'drama, romance',
#        'comedy, fantasy', 'science fiction, horror', 'adventure horror',
#        'animated', 'historical comedy', 'comedy, mystery',
#        'comedy, drama, musical', 'mystery, horror', 'comedy romance',
#        'romance, comedy', 'comedy, drama, crime', 'drama, biography',
#        'drama, action', 'sci-fi, horror', 'adventure, action',
#        'mystery, comedy', 'drama, science fiction', 'adventure, fantasy',
#        'western, musical', 'adventure, romance', 'drama, sport',
#        'musical biography', 'western, war', 'exploitation',
#        'musical western', 'murder mystery', 'comedy 2-reeler',
#        'comedy-drama', 'action, western', 'action, drama, war',
#        'sport, drama', 'serial', 'sports drama', 'drama, exploitation',
#        'animated, musical', 'military romance', 'drama, fantasy',
#        'western romance', 'western, romance', 'adventure, music',
#        'drama, music', 'mystery comedy', 'western, comedy',
#        'crime, film noir', 'suspense', 'gangster', 'biblical',
#        'epic drama', 'bio-pic', 'adventure drama', 'musical romance',
#        'musical fantasy', 'crime, sci-fi', 'comedy thriller', 'war spy',
#        'screwball comedy', 'comedy spy', 'science fiction horror',
#        'spy thriller', 'drama war', 'horror comedy',
#        'science fiction comedy', 'animated short', 'musical drama',
#        'western musical', 'sci-fi', 'western serial', 'family', 'race',
#        'charlie chan', 'cartoon', 'aviation', 'action comedy',
#        'western comedy', 'war, biography', 'war, romance',
#        'crime musical', 'fantasy thriller', 'animated comedy',
#        'musical biopic', 'short animation', 'docudrama', 'spy serial',
#        'drama, comedy; 6 separate stories', 'war documentary',
#        'propaganda short', 'propaganda short animated short',
#        'musical bio-pic', 'drama anthology', 'romantic fantasy',
#        'musical–comedy', 'horror, musical', 'war comedy',
#        'war drama propaganda', 'drama, comedy', 'crime, adventure',
#        'romantic musical', 'action western', 'western, biography',
#        'animated, war', 'war propaganda', 'biography, drama',
#        'comedy, short', 'fantasy, comedy', 'war, drama',
#        'animated, short', 'crime mystery', 'western, serial',
#        'biography, crime', 'war biography', 'short subject',
#        'family, drama', 'family, western', 'animated film',
#        'experimental', 'nature', 'educational', 'adventure, serial',
#        'black comedy', 'historic', 'slapstick', 'western, film noir',
#        'comedy–horror', 'historical epic', 'rom com', 'espionage',
#        'musical, biography', 'cold war', 'biography, musical',
#        'sports biopic', 'adventures', 'horror, 3-d', 'thriller, 3-d',
#        'sci-fi, 3-d', 'western, 3-d', 'science-fiction', 'p.o.w.',
#        'romance, trilogy', 'action drama', 'musical, drama',
#        'western, drama', 'war, western', 'comedy, biography',
#        'warner bros. drama', 'sexploitation', 'paramount. biblical epic',
#        'spy film', 'united artists. biography', 'warner bros. biography',
#        'disaster film', 'war romance', 'crime, western', 'cartoon short',
#        'drama, epic', 'sci-fi comedy', 'family comedy', 'political drama',
#        'disaster', 'adult', 'war short', 'animated musical',
#        'action, comedy', 'epic western', 'epic, biography',
#        'political thriller', 'comedy horror', 'erotic comedy',
#        'biography, war', 'travel', 'war, satire', 'comedy, satire',
#        'animated feature', 'horror musical', 'musical, fantasy',
#        'neo-noir', 'slasher', 'spy anthology', 'pow comedy',
#        'musical, family', 'family, comedy', 'compilation',
#        'comedy, action', 'western, horror', 'stop-motion animation',
#        'crime, comedy', 'experimental short', 'spy film, comedy',
#        'spy film, mystery', 'comedy, parody', 'outlaw biker film',
#        'spy comedy', 'biker drama', 'biker film', 'spy spoof',
#        'western, mystery', 'true crime', 'biography, sports', 'anthology',
#        'biker', 'musical, western', 'war, comedy', 'war, action',
#        'comedy, war', 'war, biker', 'mockumentary',
#        'psychological horror', 'crime, action', 'horror, action',
#        'animated, adult', 'sci-fi, comedy', 'disaster film, adventure',
#        'sci-fi, drama', 'blaxploitation', 'biography, crime drama',
#        'martial arts', 'crime, biography', 'thriller, adventure',
#        'adult film', 'sci-fi, action', 'science-fiction, thriller',
#        'adult, horror', 'drama, biographical', 'comedy, sports',
#        'sci-fi horror', 'erotic musical', 'horror, fantasy',
#        'animated, family', 'drama, television miniseries',
#        'action, biography', 'animated, fantasy', 'drama, family',
#        'fantasy, animated', 'superhero film', 'historical, erotic',
#        'disaster film, sci-fi', 'comedy, family', 'sci-fi drama',
#        'adventure, family', 'action, war', 'action, adventure',
#        'fantasy, thriller', 'fantasy, musical', 'drama, animated',
#        'mystery, drama', 'comedy, anthology', 'animation, family',
#        'animation, adult', '16\xa0mm film', 'action, fantasy',
#        'science fiction, comedy', 'teen', 'superhero', 'comedy, thriller',
#        'parody', 'thriller, crime', 'horror, slasher', 'action film',
#        'family drama', 'sports comedy', 'horror, thriller',
#        'erotic thriller', 'action, horror', 'sci-fi action',
#        'science fiction, drama', 'superhero, action', 'comedy, cult',
#        'cult film', 'comedy, science fiction', 'crime drama, comedy',
#        'anthology, drama', 'crime drama, action',
#        'horror and priquitianism', 'avant-garde', 'action comedy, family',
#        'animated, comedy', 'crime, romance', 'adventure, biography',
#        'rom-com', 'comedy, teen', 'action thriller', 'road thriller',
#        'action, family', 'family. drama', 'comedy action',
#        'action, drama', 'biography, comedy', 'family adventure',
#        'action, science fiction', 'science fiction, adventure',
#        'clay animation', 'family, fantasy', 'science fiction, family',
#        'science fiction, thriller', 'imax', 'student film',
#        'biogtaphy, crime, drama', 'family, mystery',
#        'disaster, science fiction', 'historical biopic', 'action, sci-fi',
#        'fantasy, sports', 'action, superhero', 'psychological thriller',
#        'crime, thriller', 'family, animated', 'historical epic, disaster',
#        'thriller, comedy', 'science fiction, fantasy, action',
#        "children's film", 'family, animation', 'science fiction thriller',
#        'drama, biopic', 'action-comedy, family',
#        'animation, science fiction, drama, family', 'comedy,horror',
#        'shakespearean', 'superhero comedy', 'teen comedy',
#        'animation, musical, comedy', 'space opera',
#        'animation comedy family', 'comedy, drama, sports', 'independent',
#        'satire', 'animation, adventure', 'action, drama, epic,',
#        'animation, fantasy', 'comedy, sci-fi', 'action, crime',
#        'war, horror', 'action, thriller', 'reality',
#        'drama, mystery, romance', 'romance, war', 'comedy-drama, fantasy',
#        'comedy-drama, romance', 'musical, romance',
#        'live-action/animation', 'fantasy, swashbuckler',
#        'action film, war', 'action, history', 'crime, family',
#        'disaster, sci-fi', 'dramedy', 'war film', 'family, superhero',
#        'western, romantic drama', 'adventure, epic fantasy,',
#        'animation, comedy', 'science fiction, action', 'fantasy, teen',
#        'drama, silent', 'action, 007', 'fantasy adventure',
#        'animation, musical', 'action, spy', 'horror, western', 'dance',
#        'drama, dance', 'romance-horror', 'martial arts/horror/comedy',
#        'comedy/drama', 'adventure/comedy/drama/family', 'family, musical',
#        'biography, western', 'parody, sports', 'dance, drama',
#        'family, sports', 'bio-pic, drama', 'bio-pic, musical',
#        'family, sci-fi', 'comedy-drama, family',
#        'adventure, swashbuckler', 'musical, thriller',
#        'fantasy, science fiction', 'drama, martial arts',
#        'adventure, mystery', 'action, crime drama',
#        'epic, science fiction', 'science fiction, animated',
#        'biography, horror', 'dance, parody',
#        'family, live-action/animated film', 'fantasy, romantic comedy',
#        'horror–thriller', 'adventure, comedy', 'black comedy, biography',
#        'war, science fiction', 'comedy horror, teen', 'concert',
#        'biography, romantic comedy', 'romantic comedy, romantic',
#        'dance, romance', 'action, martial arts', 'crime drama, biography',
#        'family, science fiction', 'action adventure, superhero',
#        'animated, comedy, drama, family', 'lgbt-themed comedy-drama',
#        'horror, mystery', 'political drama, thriller',
#        'action-adventure, fantasy', 'buddy cop, comedy',
#        'dramedy, musical', 'comedy, road', 'fantasy romance',
#        'biography, spy thriller', 'action, spy film',
#        'bio-pic, comedy-drama', 'superhero, western', 'drama comedy',
#        'action-comedy', 'action-adventure, fantasy, family',
#        'dramedy, romance', 'action thriller, fantasy',
#        'action comedy, superhero', 'action-comedy, parody',
#        'family, live-action', 'comedy, superhero', 'comedy-drama, crime',
#        'dark comedy', 'action thriller, science fiction',
#        'action horror, science fiction', 'action-adventure',
#        'action, romantic comedy', 'crime thriller, drama',
#        'sci-fi, thriller', 'adventure, comedy, fantasy',
#        'dance, drama, romance', 'dramedy, thriller', 'spoof',
#        'drama, suspense thriller', 'horror thriller',
#        'romance, science fiction, thriller', 'nature documentary',
#        'fantasy, sci-fi drama', 'romantic comedy, teen',
#        'animated, family, fantasy', 'drama, political thriller',
#        'animated, family, spy film', 'christian drama', 'sci-fi western',
#        'action thriller, sci-fi horror', 'drama, spy thriller',
#        'action, horror comedy', 'adventure, historical drama',
#        'supernatural horror, thriller', 'dance, dramedy, romance',
#        'drama, romantic comedy', 'family, live action', 'sci-fi, teen',
#        'political drama, political thriller', 'action drama, fantasy',
#        'biopic, drama', 'concert, documentary',
#        'mystery, suspense thriller', 'action, biopic',
#        'animated, sci-fi comedy', 'supernatural horror',
#        'dark comedy, thriller', 'action-adventure, family', 'legal drama',
#        'adventure, animated', 'animated, family, western',
#        'fantasy romance, horror', 'adventure, disaster',
#        'action, mystery', 'drama, teen', 'family, spy film',
#        'dark comedy, superhero', 'anthology, horror comedy',
#        'parody, horror', 'supernatural thriller',
#        'family, animated, fantasy', 'social', 'family film',
#        'family, romantic drama', 'family, direct-to-dvd',
#        'adventure, animated, fantasy', 'adventure, drama, epic',
#        'crime drama, superhero', 'family film, direct-to-dvd',
#        'animated, horror comedy', 'action thriller, adventure drama',
#        'action drama, science fiction', 'crime thriller, dark comedy',
#        'drama, gangster', 'action-adventure, drama',
#        'biopic, political drama', 'dramedy, fantasy',
#        'animated, horror comedy, thriller', 'dramedy, teen',
#        'action, horror, science fiction', 'action drama, war',
#        'action-adventure, animated, family', 'musical, romantic comedy',
#        'animated, family, 3d', 'comedy, spy film',
#        'family, sports comedy', 'drama, coming of age',
#        'anthology, horror', 'animated, comedy, family',
#        'drama, independent movie', 'bio-pic, sports', 'horror-thriller',
#        'survival', 'action drama, bio-pic, thriller', 'historical, music',
#        'adventure, animated, comedy', 'action-thriller',
#        'crime thriller, neo-noir',
#        'adventure, animated, family, fantasy-comedy', 'animated, sci-fi',
#        'animated, buddy comedy', 'animated, fantasy, musical',
#        'bio-pic, drama, music', 'boxing, comedy',
#        'action-adventure, horror', 'slahser', 'horror comedy, parody',
#        'buddy cop', 'romance, sci-fi', 'action drama, sci-fi',
#        'dark comedy, horror', 'animated, superhero',
#        'biographical, documentary', 'comedy, documentary',
#        'action-adventure, western', 'biographical, drama',
#        'documentary, music', 'crime, dark comedy', 'fantasy-comedy',
#        'buddy cop, supernatural', 'romantic thriller',
#        'comedy-drama, crime thriller', 'action-adventure, sci-fi',
#        'comedy-drama, teen', 'thriller, western', 'action, comedy-drama',
#        'documentary, family', 'horror, romantic comedy',
#        'bio-pic, black comedy', 'romantic-comedy', 'christian',
#        'animation adventure', 'animation comedy', 'animation fantasy',
#        'animated adventure', 'romance thriller', 'romantic comedy-drama',
#        'science fiction psychological thriller ',
#        'drama horror thriller film', 'science fiction mystery', 'anime',
#        'biographical drama ', 'adventure science fiction',
#        'crime comedy-drama ', 'action adventure science fiction',
#        'adventure thriller', 'adventure-comedy',
#        'biographical comedy-drama', 'western thriller',
#        'biographical political thriller',
#        'animation martial arts action-comedy', 'comedy-horror',
#        'fantasy action', 'science fiction psychological thriller',
#        'romance dramedy', 'science fiction adventure',
#        'science fiction drama supernatural', 'science fiction action',
#        'fantasy action adventure', 'superhero action adventure',
#        'science fiction action-comedy', 'mockumentary comedy',
#        'social science fiction action', 'supernatural comedy',
#        'science fiction action adventure',
#        'action adventure thriller spy', 'crime dramedy',
#        "auli'i cravalho dwayne johnson",
#        'reese witherspoon scarlett johansson',
#        'animation, adventure, sci-fi', 'horror, thriller, drama',
#        'crime, drama, thriller', 'action, adventure, horror, sci-fi',
#        'sci-fi, adventure, romance', 'animation, comedy, action',
#        'neo-noir, action, thriller', 'thriller, fantasy',
#        'horror, suspense', 'action, crime, drama',
#        'post-apocalyptic, zombie', 'action, adventure, superhero, drama',
#        'action, adventure, fantasy, sci-fi',
#        'fantasy, adventure, musical, drama, romance',
#        'action, horror, thriller', 'action, adventure, drama, superhero',
#        'action, adventure, crime, sci-fi', 'romance, drama, sci-fi',
#        'animation, comedy, fantasy, family', 'sci-fi, animation, comedy',
#        'sci-fi, drama, thriller', 'superhero, comedy, adventure, sci-fi',
#        'action, adventure, epic', 'action, adventure, fantasy, comedy',
#        'comedy, drama, war',
#        'superhero, action, adventure, fantasy, drama, war',
#        'animation, action, comedy, family', 'comedy, drama, romance',
#        'action, adventure, fantasy, horror', ' usa, can ',
#        'animation, sports, comedy, drama', 'action, adventure, sci-fi',
#        'romance, comedy, drama', 'romance, horror, thriller',
#        'comedy, action, crime', 'action, adventure, drama, fantasy',
#        'animation, comedy, adventure, action',
#        'drama, fantasy, horror, romance',
#        'action, adventure, superhero, comedy, sci-fi',
#        'sci-fi, adventure, drama, action', 'thriller, horror',
#        'sci-fi, action, adventure', 'thriller, action',
#        'animation, comedy, adventure',
#        'action, fantasy, adventure, horror, sci-fi, western',
#        'thriller, sci-fi, action', ' usa ', 'horror, fantasy, drama',
#        'action, adventure, comedy',
#        'animation, action, comedy, martial arts',
#        'biography, sports, comedy, drama',
#        'biography, action, comedy, crime, drama, history, thriller',
#        'horror, sci-fi, drama', 'neo-noir, sci-fi, thriller, mystery',
#        'romance, disaster',
#        'animation, adventure, comedy, family, fantasy, musical',
#        'drama, action, thriller', 'horror, mystery, thriller',
#        'biography, drama, thriller', 'action, sci-fi, thriller',
#        'action, biography, drama',
#        'comedy, drama, horror, mystery, thriller',
#        'biography, war, drama', 'crime, comedy, drama, mystery, thriller',
#        'crime, horror, mystery, thriller',
#        'superhero, action, adventure, fantasy, sci-fi, comedy',
#        'mystery, crime, drama', 'comedy, crime, drama, thriller',
#        'action, horror, comedy',
#        'superhero, action, adventure, fantasy, sci-fi',
#        'animation, adventure, comedy',
#        'animation, musical, fantasy, mystery', 'biography, comedy, drama',
#        'fantasy, horror, romance, sci-fi, thriller',
#        'animation, adventure, comedy, family', 'sci-fi, action, thriller',
#        'action, fantasy, adventure, comedy', 'biography, musical, drama',
#        'sci-fi, comedy, drama', 'biography, drama, history, thriller',
#        'action, fantasy, sci-fi', 'crime, drama, mystery',
#        'biography, crime, drama'], dtype=object)

# %% [markdown]
# ### Tokenize

# %%
# Install the spacy model
# !python3 -m spacy download en_core_web_sm

# %%
from spacy.lang.en.stop_words import STOP_WORDS

spacy_nlp = spacy.load('en_core_web_sm')

punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS

def tokenizer(sentence):
    sentence = re.sub('\'','',sentence)  # Removes single quotes from the sentence.
    sentence = re.sub('\w*\d\w*','',sentence)  # Removes words containing digits.
    sentence = re.sub(' +',' ',sentence)  # Replaces multiple spaces with a single space.
    sentence = re.sub(r'\n: \'\'.*','',sentence)  # Removes lines starting with ": ''".
    sentence = re.sub(r'\n!.*','',sentence)  # Removes lines starting with "!".
    sentence = re.sub(r'^:\'\'.*','',sentence)  # Removes lines starting with ":'".
    sentence = re.sub(r'\n',' ',sentence)  # Replaces newline characters with spaces.
    sentence = re.sub(r'[^\w\s]',' ',sentence)  # Removes all non-alphanumeric characters except spaces.
    tokens = spacy_nlp(sentence)
    tokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens]
    tokens = [word for word in tokens if word not in stop_words and word not in punctuations and len(word) > 2]
    return tokens

# %%
#Tokenizing (17 minutes)

am_movies['plot_tokenized'] = am_movies['Plot'].map(lambda x: tokenizer(x))

am_movies.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
#
#                                       plot_tokenized
# 0  [bartender, work, saloon, serve, drink, custom...
# 1  [moon, paint, smile, face, hang, park, night, ...
# 2  [film, minute, long, compose, shot, girl, sit,...
# 3  [second, consist, shot, shot, set, wood, winte...
# 4  [early, know, adaptation, classic, fairytale, ...

# %% [markdown]
# ### Save the tokenized data

# %%
# Save the DataFrame as a CSV file in the raw_data folder
am_movies.to_csv('../raw_data/am_movies_with_tokenized_plots.csv', index=False)

# %%
# Load the tokenized DataFrame
df_movies = pd.read_csv('../raw_data/am_movies_with_tokenized_plots.csv')
df_movies.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
#
#                                       plot_tokenized
# 0  ['bartender', 'work', 'saloon', 'serve', 'drin...
# 1  ['moon', 'paint', 'smile', 'face', 'hang', 'pa...
# 2  ['film', 'minute', 'long', 'compose', 'shot', ...
# 3  ['second', 'consist', 'shot', 'shot', 'set', '...
# 4  ['early', 'know', 'adaptation', 'classic', 'fa...

# %% [markdown]
# ### Save a small dataframe to use the titles for the search function

# %%
am_movies['Release Year'] = am_movies['Release Year'].astype('int16')  # Example for integers
am_titles = am_movies.drop(columns=['Plot', 'plot_tokenized'])
# Save the DataFrame as a Feather file
am_titles.to_feather('../model/am_titles.feather') # 1.4 MB

# %%
# Load the DataFrame from the Feather file
am_titles = pd.read_feather('../model/am_titles.feather')
am_titles.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director  Cast    Genre  \
# 0                             Unknown  None  unknown
# 1                             Unknown  None  unknown
# 2                             Unknown  None  unknown
# 3                             Unknown  None  unknown
# 4  George S. Fleming, Edwin S. Porter  None  unknown
#
#                                            Wiki Page
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...

# %% [markdown]
# ### Save the model

# %%
am_movie_plot = am_movies['plot_tokenized']
am_movie_plot[0:5]
# Out:
# 0    [bartender, work, saloon, serve, drink, custom...
# 1    [moon, paint, smile, face, hang, park, night, ...
# 2    [film, minute, long, compose, shot, girl, sit,...
# 3    [second, consist, shot, shot, set, wood, winte...
# 4    [early, know, adaptation, classic, fairytale, ...
# Name: plot_tokenized, dtype: object

# %%
from gensim import corpora

am_dictionary = corpora.Dictionary(am_movie_plot)

#note: "movie", "film"
stoplist = set('hello and if this can would should could tell ask stop come go movie film'.split())
stop_ids = [am_dictionary.token2id[stopword] for stopword in stoplist if stopword in am_dictionary.token2id]
am_dictionary.filter_tokens(stop_ids)

# %%
from pathlib import Path

# Create ../model folder if it doesn't exist
Path('../model/').mkdir(parents=True, exist_ok=True)

# %%
# Save the dictionary to the ../model folder
am_dictionary.save('../model/am_dictionary.dict')

# %%
# File paths
am_dictionary_path = '../model/am_dictionary.dict'
# Calculate file sizes
am_dictionary_size = os.path.getsize(am_dictionary_path) / (1024 * 1024)      # Convert bytes to MB
# Print file sizes
print(f"Size of am_dictionary: {am_dictionary_size:.2f} MB")
# Out:
# Size of am_dictionary: 2.02 MB

# %%
from gensim import corpora

# Load the dictionary from the ../model folder
am_dictionary = corpora.Dictionary.load('../model/am_dictionary.dict')

# %%
am_corpus = [am_dictionary.doc2bow(desc) for desc in am_movie_plot]

# %%
import gensim
from gensim.models.coherencemodel import CoherenceModel

#Create a TF-IDF model

movie_tfidf_am_model = gensim.models.TfidfModel(am_corpus, id2word=am_dictionary)

# %%
# Save the TF-IDF model to the ../model folder
movie_tfidf_am_model.save('../model/movie_tfidf_am_model')

# %%
import os

# File paths
tfidf_am_model_path = '../model/movie_tfidf_am_model'
# Calculate file sizes
tfidf_am_model_size = os.path.getsize(tfidf_am_model_path) / (1024 * 1024)      # Convert bytes to MB
# Print file sizes
print(f"Size of movie_tfidf_am_model: {tfidf_am_model_size:.2f} MB")
# Out:
# Size of movie_tfidf_am_model: 4.78 MB

# %%
from gensim import models

# Load the TF-IDF model from the ../model folder
movie_tfidf_am_model = models.TfidfModel.load('../model/movie_tfidf_am_model')

# %%
# Create the LSI model with 2000 topics (takes 2 min)
movie_lsi_am_model = gensim.models.LsiModel(movie_tfidf_am_model[am_corpus], id2word=am_dictionary, num_topics=2000)

# %% [markdown]
# When you save an `LsiModel` using the `save()` method, Gensim splits the model's data into multiple files for efficiency and modularity. The `projection.u.npy` file is one of these files, and it specifically stores the U matrix.
#
# Gensim creates several files in the `../models` directory:
#
# `movie_lsi_am_model` (main metadata file).
# `movie_lsi_am_model.projection.u.npy` (left singular vectors).
# `movie_lsi_am_model.projection.s.npy` (singular values).
# `movie_lsi_am_model.state` (model state information).
#
# When you load the `LsiModel` using the `load()` method Gensim automatically reads the `projection.u.npy` file (along with other associated files) to reconstruct the model. You typically don’t need to interact with this file directly unless you are debugging or analyzing the internal workings of the LSI model.

# %%
# Save the LSI model
movie_lsi_am_model.save('../model/movie_lsi_am_model')

# %%
# File paths
lsi_am_model_path = '../models/movie_lsi_am_model'
lsi_am_model_projection_u_path = '../models/movie_lsi_am_model.projection.u.npy'
#lsi_am_model_projection_s_path = '../models/projection.s.npy'
#lsi_am_model_state_path = '../models/movie_lsi_am_model.state'

# Calculate file sizes
lsi_am_model_size = os.path.getsize(lsi_am_model_path) / (1024 * 1024)      # Convert bytes to MB
lsi_am_model_projection_u_size = os.path.getsize(lsi_am_model_projection_u_path) / (1024 * 1024)      # Convert bytes to MB
#lsi_am_model_projection_s_size = os.path.getsize(lsi_am_model_projection_s_path) / (1024 * 1024)      # Convert bytes to MB
#lsi_am_model_state_size = os.path.getsize(lsi_am_model_state_path) / (1024 * 1024)      # Convert bytes to MB

# Print file sizes
print(f"Size of movie_lsi_am_model: {lsi_am_model_size:.2f} MB")
print(f"Size of movie_lsi_am_model.projection.u: {lsi_am_model_projection_u_size:.2f} MB")
#print(f"Size of movie_lsi_am_model.projection.s: {lsi_am_model_projection_s_size:.2f} MB")
#print(f"Size of movie_lsi_am_model.state: {lsi_am_model_state_size:.2f} MB")
# Out:
# Size of movie_lsi_am_model: 2.70 MB
# Size of movie_lsi_am_model.projection.u: 1302.49 MB

# %%
# Load the LSI model from the ../model folder
from gensim import models

movie_lsi_am_model = models.LsiModel.load('../model/movie_lsi_am_model')

# %%
# Transform the TF-IDF corpus into the LSI space
movie_lsi_am_corpus = movie_lsi_am_model[movie_tfidf_am_model[am_corpus]]

# Transform the original BoW corpus into the TF-IDF space
movie_tfidf_am_corpus = movie_tfidf_am_model[am_corpus]

# %%
# Serialize and Store the corpus locally
# (note the .index files created alongside the mm corpus files)
gensim.corpora.MmCorpus.serialize('../model/movie_tfidf_am_model_mm', movie_tfidf_am_model[am_corpus])
gensim.corpora.MmCorpus.serialize('../model/movie_lsi_am_model_mm',movie_lsi_am_model[movie_tfidf_am_model[am_corpus]])

# %%
# File paths
tfidf_model_path = '../model/movie_tfidf_am_model_mm'
lsi_model_path = '../model/movie_lsi_am_model_mm'

# Calculate file sizes
tfidf_model_size = os.path.getsize(tfidf_model_path) / (1024 * 1024)  # Convert bytes to MB
lsi_model_size = os.path.getsize(lsi_model_path) / (1024 * 1024)      # Convert bytes to MB

# Print file sizes
print(f"Size of movie_tfidf_am_model_mm: {tfidf_model_size:.2f} MB")
print(f"Size of movie_lsi_am_model_mm: {lsi_model_size:.2f} MB")
# Out:
# Size of movie_tfidf_am_model_mm: 70.96 MB
# Size of movie_lsi_am_model_mm: 1039.94 MB
