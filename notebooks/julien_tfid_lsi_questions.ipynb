# %% [markdown]
# All code based on
#
# https://www.kaggle.com/code/ajitrajput/semantic-search-engine-using-nlp/notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import spacy
import string
import gensim
import operator
import re

# %%
# %load_ext autoreload

# %autoreload 2

# %% [markdown]
# ## Tokenize

# %%
df_movies = pd.read_csv('../raw_data/wiki_movie_plots_deduped.csv')
df_movies.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34886 entries, 0 to 34885
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      34886 non-null  int64
#  1   Title             34886 non-null  object
#  2   Origin/Ethnicity  34886 non-null  object
#  3   Director          34886 non-null  object
#  4   Cast              33464 non-null  object
#  5   Genre             34886 non-null  object
#  6   Wiki Page         34886 non-null  object
#  7   Plot              34886 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
# Install the spacy model
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 18.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from spacy.lang.en.stop_words import STOP_WORDS
import spacy
import string
import re

# Load spaCy model once outside the function
spacy_nlp = spacy.load('en_core_web_sm')
punctuations = string.punctuation
stop_words = STOP_WORDS

# Precompile regular expressions
RE_APOSTROPHE = re.compile(r'\'')
RE_DIGITS = re.compile(r'\w*\d\w*')
RE_MULTIPLE_SPACES = re.compile(r' +')
RE_NEWLINE_COLON = re.compile(r'\n: \'\'.*')
RE_NEWLINE_EXCLAMATION = re.compile(r'\n!.*')
RE_COLON_START = re.compile(r'^:\'\'.*')
RE_NEWLINE = re.compile(r'\n')
RE_SPECIAL_CHARS = re.compile(r'[^\w\s]')

def tokenizer_optimized(sentence):
    """Optimized version of the tokenizer function"""
    # Combine regex operations where possible
    sentence = RE_APOSTROPHE.sub('', sentence)
    sentence = RE_DIGITS.sub('', sentence)
    sentence = RE_MULTIPLE_SPACES.sub(' ', sentence)
    sentence = RE_NEWLINE_COLON.sub('', sentence)
    sentence = RE_NEWLINE_EXCLAMATION.sub('', sentence)
    sentence = RE_COLON_START.sub('', sentence)
    sentence = RE_NEWLINE.sub(' ', sentence)
    sentence = RE_SPECIAL_CHARS.sub(' ', sentence)
    
    # Use spaCy's pipe for batch processing if you're processing multiple documents
    doc = spacy_nlp(sentence)
    
    # Use list comprehension with all conditions in one pass
    tokens = [
        word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_
        for word in doc
        if (word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_) not in stop_words
        and (word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_) not in punctuations
        and len(word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_) > 2
    ]
    
    return tokens

# %%
from spacy.lang.en.stop_words import STOP_WORDS

spacy_nlp = spacy.load('en_core_web_sm')

punctuations = string.punctuation
stop_words = spacy.lang.en.stop_words.STOP_WORDS

def tokenizer(sentence):
    sentence = re.sub('\'','',sentence)
    sentence = re.sub('\w*\d\w*','',sentence)
    sentence = re.sub(' +',' ',sentence)
    sentence = re.sub(r'\n: \'\'.*','',sentence)
    sentence = re.sub(r'\n!.*','',sentence)
    sentence = re.sub(r'^:\'\'.*','',sentence)
    sentence = re.sub(r'\n',' ',sentence)
    sentence = re.sub(r'[^\w\s]',' ',sentence)
    tokens = spacy_nlp(sentence)
    tokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in tokens]
    tokens = [word for word in tokens if word not in stop_words and word not in punctuations and len(word) > 2]
    return tokens

# %%
import time

start_time = time.time()

print ('Cleaning and Tokenizing...') # 28 minutes!
df_movies['wiki_plot_tokenized'] = df_movies['Plot'].map(lambda x: tokenizer_optimized(x))

end_time = time.time()
execution_time = end_time - start_time

print(f"Tokenization completed in {execution_time:.2f} seconds ({execution_time/60:.2f} minutes)")

df_movies.head()
# Out:
# Cleaning and Tokenizing...
# Tokenization completed in 2625.59 seconds (43.76 minutes)
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
#
#                                  wiki_plot_tokenized
# 0  [bartender, work, saloon, serve, drink, custom...
# 1  [moon, paint, smile, face, hang, park, night, ...
# 2  [film, minute, long, compose, shot, girl, sit,...
# 3  [second, consist, shot, shot, set, wood, winte...
# 4  [early, know, adaptation, classic, fairytale, ...

# %%
# Save the DataFrame as a CSV file in the raw_data folder
df_movies.to_csv('../raw_data/movies_with_tokenized_plots.csv', index=False)

# %% [markdown]
# ## Load tokenized data

# %% [markdown]
# When saving the tokenized data to a CSV file, it gets converted to a string representation. When loading it back, it remains a string instead of being converted back to a list of tokens.
#
# To resolve this issue, you can use the ast module to safely evaluate the string representation of the lists back into actual lists of tokens.

# %%
import pandas as pd
import ast

# Load the DataFrame from the CSV file
df_movies = pd.read_csv('../raw_data/movies_with_tokenized_plots.csv')

# Convert the string representation of lists back into actual lists of tokens
df_movies['wiki_plot_tokenized'] = df_movies['wiki_plot_tokenized'].apply(ast.literal_eval)

df_movies.head()

# Now you can use df_movies['wiki_plot_tokenized'] as lists of tokens
movie_plot = df_movies['wiki_plot_tokenized']

# %%
movie_plot[0:5]
# Out:
# 0    [bartender, work, saloon, serve, drink, custom...
# 1    [moon, paint, smile, face, hang, park, night, ...
# 2    [film, minute, long, compose, shot, girl, sit,...
# 3    [second, consist, shot, shot, set, wood, winte...
# 4    [early, know, adaptation, classic, fairytale, ...
# Name: wiki_plot_tokenized, dtype: object

# %%
movie_plot[0][:5]
# Out:
# ['bartender', 'work', 'saloon', 'serve', 'drink']

# %% [markdown]
# Concatenate all the arrays in `movie_plot`, convert the result into a Pandas Series, count the frequency of each unique value, and select the top 100 most frequent values. Create a word cloud where the size of each word is proportional to its frequency.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

series = pd.Series(np.concatenate(movie_plot)).value_counts()[:100]
wordcloud = WordCloud(background_color='white').generate_from_frequencies(series)

plt.figure(figsize=(15,15), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Word Dictionary Creation¶

# %% [markdown]
# In `gensim`, words are referred as “tokens” and the index of each word in the dictionary is called ID.

# %% [markdown]
# Create a Dictionary object from the `movie_plot` list. Each unique token in `movie_plot` is assigned a unique integer ID. Create a list of token IDs for the stop words in the set `stoplist`. Creates a list of token IDs for the stop words and filter out the tokens with theses IDs from `dictionary`.

# %% [markdown]
# All the tokens in the dictionary which either have occurred in less than 4 articles or have occurred in more than 20% of the articles are removed from the dictionary, as these words will not be contributing to the various themes or topics.

# %%
from gensim import corpora

dictionary = corpora.Dictionary(movie_plot)

# %%
print(list(dictionary.items())[:10])
# Out:
# [(0, 'appear'), (1, 'assault'), (2, 'bar'), (3, 'bartender'), (4, 'beer'), (5, 'begin'), (6, 'break'), (7, 'bucket'), (8, 'burst'), (9, 'carrie')]

# %%
set('hello and if this can would should could tell ask stop come go movie film'.split())
# Out:
# {'and',
#  'ask',
#  'can',
#  'come',
#  'could',
#  'film',
#  'go',
#  'hello',
#  'if',
#  'movie',
#  'should',
#  'stop',
#  'tell',
#  'this',
#  'would'}

# %%
from gensim import corpora

dictionary = corpora.Dictionary(movie_plot)

#filter out terms which occurs in less than 4 documents and more than 20% of the documents.
#NOTE: Since we have smaller dataset, we will keep this commented for now.

dictionary.filter_extremes(no_below=4, no_above=0.2)

stoplist = set('hello and if this can would should could tell ask stop come go movie film'.split())
stop_ids = [dictionary.token2id[stopword] for stopword in stoplist if stopword in dictionary.token2id]
dictionary.filter_tokens(stop_ids)

# %%
dictionary.token2id
# Out:
# {'appear': 0,
#  'assault': 1,
#  'bar': 2,
#  'bartender': 3,
#  'beer': 4,
#  'break': 5,
#  'bucket': 6,
#  'burst': 7,
#  'carrie': 8,
#  'cash': 9,
#  'customer': 10,
#  'drink': 11,
#  'dump': 12,
#  'everybody': 13,
#  'eye': 14,
#  'face': 15,
#  'fill': 16,
#  'fixture': 17,
#  'follower': 18,
#  'group': 19,
#  'hat': 20,
#  'head': 21,
#  'inside': 22,
#  'irish': 23,
#  'mirror': 24,
#  'nation': 25,
#  'nations': 26,
#  'order': 27,
#  'policeman': 28,
#  'pull': 29,
#  'register': 30,
#  'saloon': 31,
#  'seltzer': 32,
#  'serve': 33,
#  'smash': 34,
#  'spray': 35,
#  'stereotypically': 36,
#  'water': 37,
#  'wreck': 38,
#  'bench': 39,
#  'big': 40,
#  'block': 41,
#  'cause': 42,
#  'couple': 43,
#  'embrace': 44,
#  'fan': 45,
#  'fence': 46,
#  'frown': 47,
#  'hang': 48,
#  'look': 49,
#  'moon': 50,
#  'paint': 51,
#  'park': 52,
#  'past': 53,
#  'perch': 54,
#  'railing': 55,
#  'scene': 56,
#  'shoulder': 57,
#  'sit': 58,
#  'sky': 59,
#  'smile': 60,
#  'tree': 61,
#  'view': 62,
#  'walk': 63,
#  'abraham': 64,
#  'altar': 65,
#  'assassin': 66,
#  'assassination': 67,
#  'base': 68,
#  'camera': 69,
#  'center': 70,
#  'compose': 71,
#  'display': 72,
#  'foot': 73,
#  'garfield': 74,
#  'girl': 75,
#  'hide': 76,
#  'james': 77,
#  'justice': 78,
#  'kneel': 79,
#  'lady': 80,
#  'lincoln': 81,
#  'long': 82,
#  'mckinley': 83,
#  'minute': 84,
#  'portal': 85,
#  'portrait': 86,
#  'president': 87,
#  'second': 88,
#  'shot': 89,
#  'tomb': 90,
#  'victim': 91,
#  'william': 92,
#  'actor': 93,
#  'agent': 94,
#  'aim': 95,
#  'aloft': 96,
#  'bear': 97,
#  'cat': 98,
#  'closely': 99,
#  'cock': 100,
#  'common': 101,
#  'consist': 102,
#  'different': 103,
#  'dutifully': 104,
#  'enthusiastically': 105,
#  'fell': 106,
#  'follow': 107,
#  'foreground': 108,
#  'hillside': 109,
#  'hold': 110,
#  'horse': 111,
#  'hurry': 112,
#  'left': 113,
#  'note': 114,
#  'path': 115,
#  'photographer': 116,
#  'press': 117,
#  'prize': 118,
#  'proceed': 119,
#  'read': 120,
#  'represent': 121,
#  'respectively': 122,
#  'ride': 123,
#  'rifle': 124,
#  'right': 125,
#  'roosevelt': 126,
#  'set': 127,
#  'sign': 128,
#  'slightly': 129,
#  'stab': 130,
#  'teddy': 131,
#  'theodore': 132,
#  'upward': 133,
#  'vice': 134,
#  'winter': 135,
#  'wood': 136,
#  'able': 137,
#  'adaptation': 138,
#  'ascend': 139,
#  'await': 140,
#  'bean': 141,
#  'beanstalk': 142,
#  'celebrate': 143,
#  'chase': 144,
#  'classic': 145,
#  'climb': 146,
#  'cow': 147,
#  'cut': 148,
#  'deposed': 149,
#  'drop': 150,
#  'early': 151,
#  'enter': 152,
#  'fairy': 153,
#  'fairytale': 154,
#  'giant': 155,
#  'giants': 156,
#  'glimpse': 157,
#  'grow': 158,
#  'jack': 159,
#  'king': 160,
#  'narrowly': 161,
#  'prince': 162,
#  'safety': 163,
#  'sleep': 164,
#  'stalk': 165,
#  'trade': 166,
#  'upstairs': 167,
#  'version': 168,
#  'visit': 169,
#  'wake': 170,
#  'yard': 171,
#  'alice': 172,
#  'baby': 173,
#  'bottle': 174,
#  'box': 175,
#  'card': 176,
#  'cheshire': 177,
#  'child': 178,
#  'cook': 179,
#  'direct': 180,
#  'disappear': 181,
#  'dog': 182,
#  'door': 183,
#  'dream': 184,
#  'duchesss': 185,
#  'ear': 186,
#  'eat': 187,
#  'enable': 188,
#  'executioner': 189,
#  'flee': 190,
#  'garden': 191,
#  'grip': 192,
#  'hole': 193,
#  'infant': 194,
#  'invite': 195,
#  'join': 196,
#  'kitchen': 197,
#  'label': 198,
#  'large': 199,
#  'mad': 200,
#  'magic': 201,
#  'march': 202,
#  'normal': 203,
#  'offend': 204,
#  'outside': 205,
#  'parade': 206,
#  'party': 207,
#  'pass': 208,
#  'persuade': 209,
#  'pig': 210,
#  'play': 211,
#  'playing': 212,
#  'procession': 213,
#  'queen': 214,
#  'rabbit': 215,
#  'rabbits': 216,
#  'realize': 217,
#  'resume': 218,
#  'royal': 219,
#  'shrink': 220,
#  'size': 221,
#  'squirm': 222,
#  'suddenly': 223,
#  'summon': 224,
#  'tea': 225,
#  'thing': 226,
#  'throw': 227,
#  'tiny': 228,
#  'unintentionally': 229,
#  'white': 230,
#  'awaken': 231,
#  'bandit': 232,
#  'belonging': 233,
#  'bind': 234,
#  'board': 235,
#  'bring': 236,
#  'car': 237,
#  'carry': 238,
#  'collapse': 239,
#  'comic': 240,
#  'consciousness': 241,
#  'dance': 242,
#  'disconnect': 243,
#  'douse': 244,
#  'dynamite': 245,
#  'eastern': 246,
#  'engineer': 247,
#  'express': 248,
#  'final': 249,
#  'fire': 250,
#  'fireman': 251,
#  'form': 252,
#  'free': 253,
#  'gunpoint': 254,
#  'hall': 255,
#  'halt': 256,
#  'instantly': 257,
#  'knock': 258,
#  'local': 259,
#  'locomotive': 260,
#  'loot': 261,
#  'mail': 262,
#  'meal': 263,
#  'messenger': 264,
#  'office': 265,
#  'open': 266,
#  'operator': 267,
#  'overtake': 268,
#  'passenger': 269,
#  'posse': 270,
#  'quickly': 271,
#  'railroad': 272,
#  'recover': 273,
#  'relief': 274,
#  'restore': 275,
#  'robbery': 276,
#  'rush': 277,
#  'shoot': 278,
#  'shootout': 279,
#  'station': 280,
#  'steal': 281,
#  'stranger': 282,
#  'tank': 283,
#  'telegraph': 284,
#  'tender': 285,
#  'tie': 286,
#  'train': 287,
#  'transmit': 288,
#  'valley': 289,
#  'valuable': 290,
#  'arrest': 291,
#  'crockery': 292,
#  'hope': 293,
#  'quiet': 294,
#  'suburb': 295,
#  'violent': 296,
#  'wrong': 297,
#  'abandon': 298,
#  'agree': 299,
#  'alarm': 300,
#  'appearance': 301,
#  'approach': 302,
#  'avoid': 303,
#  'axe': 304,
#  'bandage': 305,
#  'bank': 306,
#  'barely': 307,
#  'barn': 308,
#  'bed': 309,
#  'bedraggle': 310,
#  'believe': 311,
#  'belt': 312,
#  'bend': 313,
#  'blindfold': 314,
#  'boat': 315,
#  'bridge': 316,
#  'bush': 317,
#  'cabin': 318,
#  'candy': 319,
#  'capture': 320,
#  'cartridge': 321,
#  'chance': 322,
#  'charge': 323,
#  'climax': 324,
#  'close': 325,
#  'clothe': 326,
#  'confederate': 327,
#  'congratulate': 328,
#  'crestfallen': 329,
#  'criminal': 330,
#  'cross': 331,
#  'decorate': 332,
#  'den': 333,
#  'desperado': 334,
#  'divide': 335,
#  'doll': 336,
#  'dozen': 337,
#  'drag': 338,
#  'dress': 339,
#  'elude': 340,
#  'embankment': 341,
#  'engine': 342,
#  'entire': 343,
#  'evidently': 344,
#  'exciting': 345,
#  'exploit': 346,
#  'famous': 347,
#  'far': 348,
#  'finally': 349,
#  'fitting': 350,
#  'foremost': 351,
#  'frightened': 352,
#  'gallantly': 353,
#  'gang': 354,
#  'hand': 355,
#  'hard': 356,
#  'heartily': 357,
#  'heel': 358,
#  'hesitate': 359,
#  'hill': 360,
#  'hit': 361,
#  'hurried': 362,
#  'ideal': 363,
#  'illustrate': 364,
#  'immediately': 365,
#  'interior': 366,
#  'job': 367,
#  'jump': 368,
#  'knife': 369,
#  'leader': 370,
#  'like': 371,
#  'lively': 372,
#  'load': 373,
#  'lounge': 374,
#  'meantime': 375,
#  'member': 376,
#  'mix': 377,
#  'mountain': 378,
#  'muzzle': 379,
#  'notorious': 380,
#  'novel': 381,
#  'oblige': 382,
#  'obstruction': 383,
#  'opening': 384,
#  'opposite': 385,
#  'overboard': 386,
#  'paper': 387,
#  'particular': 388,
#  'pick': 389,
#  'picket': 390,
#  'picture': 391,
#  'place': 392,
#  'plunder': 393,
#  'pond': 394,
#  'pony': 395,
#  'principally': 396,
#  'pursuer': 397,
#  'pursuit': 398,
#  'raise': 399,
#  'reach': 400,
#  'recruit': 401,
#  'remainder': 402,
#  'remove': 403,
#  'rescue': 404,
#  'resemble': 405,
#  'respond': 406,
#  'revolver': 407,
#  'road': 408,
#  'robber': 409,
#  'room': 410,
#  'rope': 411,
#  'round': 412,
#  'search': 413,
#  'secure': 414,
#  'senseles': 415,
#  'sentry': 416,
#  'seven': 417,
#  'shake': 418,
#  'shallow': 419,
#  'sight': 420,
#  'sneak': 421,
#  'solemnly': 422,
#  'soon': 423,
#  'spot': 424,
#  'steep': 425,
#  'stream': 426,
#  'strike': 427,
#  'successfully': 428,
#  'surround': 429,
#  'swear': 430,
#  'tall': 431,
#  'track': 432,
#  'trail': 433,
#  'trusted': 434,
#  'tussle': 435,
#  'typical': 436,
#  'unable': 437,
#  'uncouple': 438,
#  'volunteer': 439,
#  'wait': 440,
#  'walking': 441,
#  'wall': 442,
#  'weed': 443,
#  'western': 444,
#  'wild': 445,
#  'youthful': 446,
#  'children': 447,
#  'chimney': 448,
#  'city': 449,
#  'claus': 450,
#  'engage': 451,
#  'enjoy': 452,
#  'feed': 453,
#  'fight': 454,
#  'finish': 455,
#  'harry': 456,
#  'household': 457,
#  'introduce': 458,
#  'line': 459,
#  'pillow': 460,
#  'poem': 461,
#  'present': 462,
#  'real': 463,
#  'reindeer': 464,
#  'santa': 465,
#  'sleigh': 466,
#  'stair': 467,
#  'stocking': 468,
#  'workshop': 469,
#  'atop': 470,
#  'bedroom': 471,
#  'catch': 472,
#  'ceiling': 473,
#  'container': 474,
#  'crash': 475,
#  'desperately': 476,
#  'dizzy': 477,
#  'emerge': 478,
#  'eventually': 479,
#  'fiend': 480,
#  'float': 481,
#  'fly': 482,
#  'furniture': 483,
#  'gorge': 484,
#  'hallucinate': 485,
#  'hallucinatory': 486,
#  'lamppost': 487,
#  'poke': 488,
#  'restaurant': 489,
#  'sequence': 490,
#  'spin': 491,
#  'steeple': 492,
#  'tear': 493,
#  'welsh': 494,
#  'wildly': 495,
#  'window': 496,
#  'world': 497,
#  'cart': 498,
#  'create': 499,
#  'feature': 500,
#  'getaway': 501,
#  'log': 502,
#  'occupant': 503,
#  'rob': 504,
#  'rockies': 505,
#  'systematically': 506,
#  'thug': 507,
#  'travel': 508,
#  'wealthy': 509,
#  'captain': 510,
#  'celebration': 511,
#  'charles': 512,
#  'control': 513,
#  'debt': 514,
#  'generation': 515,
#  'historian': 516,
#  'judge': 517,
#  'kathleen': 518,
#  'marriage': 519,
#  'owe': 520,
#  'porters': 521,
#  'renew': 522,
#  'save': 523,
#  'tenant': 524,
#  'terence': 525,
#  'village': 526,
#  'villager': 527,
#  'villain': 528,
#  'write': 529,
#  'abduct': 530,
#  'arrow': 531,
#  'attack': 532,
#  'befriend': 533,
#  'boone': 534,
#  'boones': 535,
#  'burn': 536,
#  'camp': 537,
#  'chief': 538,
#  'cliff': 539,
#  'companion': 540,
#  'edge': 541,
#  'encounter': 542,
#  'expedition': 543,
#  'huge': 544,
#  'hunting': 545,
#  'indian': 546,
#  'indians': 547,
#  'maiden': 548,
#  'panic': 549,
#  'stake': 550,
#  'torture': 551,
#  'vengeance': 552,
#  'backwards': 553,
#  'ballpark': 554,
#  'baseball': 555,
#  'basis': 556,
#  'brown': 557,
#  'browns': 558,
#  'cocktail': 559,
#  'escort': 560,
#  'furious': 561,
#  'game': 562,
#  'highball': 563,
#  'husband': 564,
#  'inebriated': 565,
#  'intoxication': 566,
#  'nearby': 567,
#  'physically': 568,
#  'pitcher': 569,
#  'player': 570,
#  'responsible': 571,
#  'reverse': 572,
#  'severe': 573,
#  'sport': 574,
#  'watch': 575,
#  'black': 576,
#  'dentist': 577,
#  'gas': 578,
#  'include': 579,
#  'laugh': 580,
#  'laughter': 581,
#  'officer': 582,
#  'plot': 583,
#  'situation': 584,
#  'toothache': 585,
#  'vendor': 586,
#  'barrel': 587,
#  'beautiful': 588,
#  'boy': 589,
#  'buy': 590,
#  'crew': 591,
#  'current': 592,
#  'dangerous': 593,
#  'devise': 594,
#  'distract': 595,
#  'downstream': 596,
#  'drive': 597,
#  'fish': 598,
#  'gag': 599,
#  'gypsy': 600,
#  'gypsys': 601,
#  'kidnap': 602,
#  'organize': 603,
#  'outing': 604,
#  'parent': 605,
#  'refuse': 606,
#  'reunite': 607,
#  'river': 608,
#  'safely': 609,
#  'seal': 610,
#  'summer': 611,
#  'sweep': 612,
#  'wagon': 613,
#  'ware': 614,
#  'accost': 615,
#  'neighbor': 616,
#  'rescuer': 617,
#  'revenge': 618,
#  'roof': 619,
#  'ruffian': 620,
#  'succeed': 621,
#  'trap': 622,
#  'vow': 623,
#  'workplace': 624,
#  'angry': 625,
#  'elope': 626,
#  'midst': 627,
#  'moment': 628,
#  'romantic': 629,
#  'thief': 630,
#  'trunk': 631,
#  'womans': 632,
#  'anonymous': 633,
#  'biograph': 634,
#  'brave': 635,
#  'company': 636,
#  'companys': 637,
#  'defense': 638,
#  'despite': 639,
#  'florence': 640,
#  'lawrence': 641,
#  'melodrama': 642,
#  'popular': 643,
#  'proposal': 644,
#  'reel': 645,
#  'reject': 646,
#  'rejection': 647,
#  'stock': 648,
#  'tribe': 649,
#  'war': 650,
#  'american': 651,
#  'carol': 652,
#  'change': 653,
#  'christmas': 654,
#  'dead': 655,
#  'description': 656,
#  'dismiss': 657,
#  'donate': 658,
#  'error': 659,
#  'euphoric': 660,
#  'eve': 661,
#  'exist': 662,
#  'fate': 663,
#  'generous': 664,
#  'ghost': 665,
#  'grave': 666,
#  'horrible': 667,
#  'jacob': 668,
#  'magazine': 669,
#  'marley': 670,
#  'meaning': 671,
#  'morning': 672,
#  'moving': 673,
#  'nephew': 674,
#  'partner': 675,
#  'print': 676,
#  'provide': 677,
#  'release': 678,
#  'rest': 679,
#  'result': 680,
#  'scrooge': 681,
#  'spirit': 682,
#  'warn': 683,
#  'wish': 684,
#  'border': 685,
#  'cheat': 686,
#  'jail': 687,
#  'juanita': 688,
#  'mexican': 689,
#  'murder': 690,
#  'pedro': 691,
#  'poker': 692,
#  'sheriff': 693,
#  'suspicion': 694,
#  'town': 695,
#  'uproar': 696,
#  'wound': 697,
#  'admirer': 698,
#  'church': 699,
#  'commit': 700,
#  'confession': 701,
#  'fiance': 702,
#  'fortunately': 703,
#  'suicide': 704,
#  'sweetheart': 705,
#  'addicted': 706,
#  'afternoon': 707,
#  'association': 708,
#  'beg': 709,
#  'besotte': 710,
#  'changed': 711,
#  'condition': 712,
#  'consent': 713,
#  'culminate': 714,
#  'curtain': 715,
#  'demon': 716,
#  'despair': 717,
#  'determination': 718,
#  'dramatization': 719,
#  'effect': 720,
#  'extent': 721,
#  'fasten': 722,
#  'fireside': 723,
#  'firm': 724,
#  'firmly': 725,
#  'habit': 726,
#  'happiness': 727,
#  'happy': 728,
#  'homeward': 729,
#  'inevitable': 730,
#  'john': 731,
#  'journey': 732,
#  'little': 733,
#  'peace': 734,
#  'peaceful': 735,
#  'persuasion': 736,
#  'promise': 737,
#  'question': 738,
#  'rakish': 739,
#  'rein': 740,
#  'rum': 741,
#  'seat': 742,
#  'short': 743,
#  'spectacle': 744,
#  'supper': 745,
#  'tentacle': 746,
#  'terrifying': 747,
#  'theater': 748,
#  'ticket': 749,
#  'true': 750,
#  'trust': 751,
#  'wharton': 752,
#  'wine': 753,
#  'woe': 754,
#  'zolas': 755,
#  'émile': 756,
#  'asleep': 757,
#  'borrow': 758,
#  'callous': 759,
#  'coin': 760,
#  'donor': 761,
#  'evening': 762,
#  'fortune': 763,
#  'gambler': 764,
#  'golden': 765,
#  'louis': 766,
#  'miss': 767,
#  'paris': 768,
#  'reveler': 769,
#  'roulette': 770,
#  'send': 771,
#  'shoe': 772,
#  'snowy': 773,
#  'street': 774,
#  'sure': 775,
#  'tip': 776,
#  'wander': 777,
#  'win': 778,
#  'bill': 779,
#  'farm': 780,
#  'flirt': 781,
#  'gambling': 782,
#  'good': 783,
#  'maid': 784,
#  'mary': 785,
#  'pay': 786,
#  'peddler': 787,
#  'pickford': 788,
#  'priscilla': 789,
#  'unemployed': 790,
#  'business': 791,
#  'charity': 792,
#  'committee': 793,
#  'contribute': 794,
#  'ebenezer': 795,
#  'fred': 796,
#  'future': 797,
#  'punishment': 798,
#  'rudely': 799,
#  'suffer': 800,
#  'describe': 801,
#  'edison': 802,
#  'liberal': 803,
#  'mrs': 804,
#  'shelleys': 805,
#  'aid': 806,
#  'body': 807,
#  'cloth': 808,
#  'crime': 809,
#  'crowd': 810,
#  'detective': 811,
#  'dummy': 812,
#  'expense': 813,
#  'fact': 814,
#  'hemlock': 815,
#  'hoax': 816,
#  'holmes': 817,
#  'pair': 818,
#  'people': 819,
#  'punish': 820,
#  'realization': 821,
#  'respect': 822,
#  'sherlock': 823,
#  'shred': 824,
#  'sleuth': 825,
#  'small': 826,
#  'stuff': 827,
#  'think': 828,
#  'tramp': 829,
#  'trick': 830,
#  'tropical': 831,
#  'type': 832,
#  'wear': 833,
#  'battle': 834,
#  'boyhood': 835,
#  'brother': 836,
#  'chum': 837,
#  'civil': 838,
#  'lose': 839,
#  'nerve': 840,
#  'presence': 841,
#  'secret': 842,
#  'shameful': 843,
#  'shutter': 844,
#  'sister': 845,
#  'soldier': 846,
#  'stumble': 847,
#  'title': 848,
#  'truth': 849,
#  'uniform': 850,
#  'america': 851,
#  'construction': 852,
#  'desperate': 853,
#  'destitute': 854,
#  'emigrate': 855,
#  'ireland': 856,
#  'land': 857,
#  'letter': 858,
#  'politic': 859,
#  'poverty': 860,
#  'receive': 861,
#  'success': 862,
#  'acknowledge': 863,
#  'band': 864,
#  'christianity': 865,
#  'club': 866,
#  'colonist': 867,
#  'colony': 868,
#  'convert': 869,
#  'descend': 870,
#  'england': 871,
#  'english': 872,
#  'englishman': 873,
#  'execution': 874,
#  'exploration': 875,
#  'fatal': 876,
#  'favorite': 877,
#  'fervently': 878,
#  'flower': 879,
#  'foreign': 880,
#  'handsome': 881,
#  'honor': 882,
#  'hostage': 883,
#  'hour': 884,
#  'mans': 885,
#  'october': 886,
#  'pocahontas': 887,
#  'presume': 888,
#  'princess': 889,
#  'prisoner': 890,
#  'red': 891,
#  'relent': 892,
#  'rolfe': 893,
#  'rude': 894,
#  'sail': 895,
#  'settle': 896,
#  'sicken': 897,
#  'smith': 898,
#  'spare': 899,
#  'stand': 900,
#  'state': 901,
#  'survive': 902,
#  'synopsis': 903,
#  'transplant': 904,
#  'trip': 905,
#  'virginia': 906,
#  'vision': 907,
#  'wilderness': 908,
#  'alessandro': 909,
#  'blood': 910,
#  'chronicle': 911,
#  'claim': 912,
#  'deeply': 913,
#  'demolish': 914,
#  'deny': 915,
#  'desire': 916,
#  'devastate': 917,
#  'exile': 918,
#  'felipe': 919,
#  'francis': 920,
#  'grandon': 921,
#  'henry': 922,
#  'inform': 923,
#  'moreno': 924,
#  'orphan': 925,
#  'perishe': 926,
#  'prestigious': 927,
#  'proclaim': 928,
#  'ramona': 929,
#  'ramonas': 930,
#  'ranch': 931,
#  'react': 932,
#  'romance': 933,
#  'spanish': 934,
#  'stepmother': 935,
#  'walthall': 936,
#  'wreckage': 937,
#  'absence': 938,
#  'accept': 939,
#  'accompany': 940,
#  'adieu': 941,
#  'aghast': 942,
#  'animate': 943,
#  'arm': 944,
#  'basket': 945,
#  'bid': 946,
#  'blow': 947,
#  'blue': 948,
#  'bounce': 949,
#  'brief': 950,
#  'brook': 951,
#  'cane': 952,
#  'charm': 953,
#  'cheek': 954,
#  'complicate': 955,
#  'conceal': 956,
#  'conclude': 957,
#  'confidently': 958,
#  'contact': 959,
#  'conveniently': 960,
#  'crafty': 961,
#  'cutaway': 962,
#  'daisy': 963,
#  'dejected': 964,
#  'depart': 965,
#  'diligently': 966,
#  'divine': 967,
#  'entreaty': 968,
#  'examine': 969,
#  'exchange': 970,
#  'explanation': 971,
#  'farewell': 972,
#  'farmhand': 973,
#  'field': 974,
#  'fit': 975,
#  'fortuneteller': 976,
#  'gertrude': 977,
#  'greet': 978,
#  'hasty': 979,
#  'heartbroken': 980,
#  'heed': 981,
#  'homestead': 982,
#  'horrified': 983,
#  'impulsively': 984,
#  'induce': 985,
#  'jilt': 986,
#  'jubilantly': 987,
#  'kiss': 988,
#  'labor': 989,
#  'lanky': 990,
#  'martha': 991,
#  'marthas': 992,
#  'meeting': 993,
#  'millie': 994,
#  'millies': 995,
#  'mob': 996,
#  'motion': 997,
#  'notice': 998,
#  'observe': 999,
#  ...}

# %%
stoplist #Note: film, movie
# Out:
# {'and',
#  'ask',
#  'can',
#  'come',
#  'could',
#  'film',
#  'go',
#  'hello',
#  'if',
#  'movie',
#  'should',
#  'stop',
#  'tell',
#  'this',
#  'would'}

# %%
stop_ids
# Out:
# [2072, 10590, 282]

# %% [markdown]
# Iterate over each (token ID, token) pair in the dictionary, including only first 50 tokens. For each token ID (`key`) create a list of a token (`dictionary[key]`) and its key (`dictionary.token2id[dictionary[key]]`). Create a list of these lists `dict_tokens`.

# %%
dictionary[0]
# Out:
# 'appear'

# %%
dict_tokens = [[dictionary[key], dictionary.token2id[dictionary[key]]] for key in range(min(50, len(dictionary)))]
print(dict_tokens)
# Out:
# [['appear', 0], ['assault', 1], ['bar', 2], ['bartender', 3], ['beer', 4], ['break', 5], ['bucket', 6], ['burst', 7], ['carrie', 8], ['cash', 9], ['customer', 10], ['drink', 11], ['dump', 12], ['everybody', 13], ['eye', 14], ['face', 15], ['fill', 16], ['fixture', 17], ['follower', 18], ['group', 19], ['hat', 20], ['head', 21], ['inside', 22], ['irish', 23], ['mirror', 24], ['nation', 25], ['nations', 26], ['order', 27], ['policeman', 28], ['pull', 29], ['register', 30], ['saloon', 31], ['seltzer', 32], ['serve', 33], ['smash', 34], ['spray', 35], ['stereotypically', 36], ['water', 37], ['wreck', 38], ['bench', 39], ['big', 40], ['block', 41], ['cause', 42], ['couple', 43], ['embrace', 44], ['fan', 45], ['fence', 46], ['frown', 47], ['hang', 48], ['look', 49]]

# %% [markdown]
# ## Feature Extraction (Bag of Words)¶

# %% [markdown]
# Corpus is a list where each element is the bag-of-words  (BoW) representation of a document (movie plot) from `movie_plot`.
#
# The `doc2bow` method converts a document (a list of words) into a bag-of-words (BoW) format. In this format, each document is represented as a list of `(token_id, token_count)` tuples, where `token_id` is the unique integer ID assigned to the word by the dictionary, and `token_count` is the number of occurrences of the word in the document.
#
# See above `sorted(movie_plot[0])` and `word_frequencies`: 1st token 'appear' occurs 1 time; 2nd 'assault' 1 time; 3rd 'bar' 1; 4th 'bartender' 2.
#
# `word_frequencies` is a list of lists, where each inner list contains (word, frequency) tuples for a document. The outer list contains these lists for the first three documents in the corpus.

# %%
corpus = [dictionary.doc2bow(desc) for desc in movie_plot]

word_frequencies = [[(dictionary[id], frequency) for id, frequency in line] for line in corpus[0:3]]

display(word_frequencies[0][:5])
# Out:
# [('appear', 1), ('assault', 1), ('bar', 1), ('bartender', 2), ('beer', 2)]

# %%
corpus[22][:10] # First 4 words in the first document
# Out:
# [(43, 1),
#  (127, 1),
#  (208, 1),
#  (523, 1),
#  (622, 1),
#  (646, 1),
#  (698, 1),
#  (699, 1),
#  (700, 1),
#  (701, 2)]

# %% [markdown]
# ## Build Tf-Idf and LSI Model¶

# %% [markdown]
# **Tf-Idf (Term frequency-Inverse Document Frequency)** is a commonly used NLP model that helps you determine the most important words in each document in the corpus. Once the Tf-Idf is build, pass it to LSI model and specify the num of features to build

# %% [markdown]
# Wikipedia: "**LSA (Latent Semantic Analysis)**, also known as **LSI (Latent Semantic Index)**, is a technique in natural language processing of analyzing relationships between a set of documents and the terms they contain by **producing a set of concepts related to the documents** and terms. LSI is based on the principle that words that are used in the same contexts tend to have similar meanings. A key feature of LSI is its ability to extract the conceptual content of a body of text by establishing associations between those terms that occur in similar contexts.

# %% [markdown]
# LSI examines a collection of documents to see which documents contain some of those same words. LSI considers documents that have many words in common to be semantically close, and ones with less words in common to be less close.
#
# LSI does not require an exact match to return useful results (where a plain keyword search would fail).

# %%
from gensim.models.coherencemodel import CoherenceModel

movie_tfidf_model = gensim.models.TfidfModel(corpus, id2word=dictionary)
# Create the LSI model
movie_lsi_model = gensim.models.LsiModel(movie_tfidf_model[corpus], id2word=dictionary, num_topics=300)

# Evaluate the model using topic coherence
coherence_model_lsi = CoherenceModel(model=movie_lsi_model, texts=movie_plot, dictionary=dictionary, coherence='c_v')
coherence_lsi = coherence_model_lsi.get_coherence()

print(f'Coherence Score: {coherence_lsi}')
# Out:
# Coherence Score: 0.3827195879369458

# %% [markdown]
# **Above** `gensim.models.TfidfModel` initializes a TF-IDF (Term Frequency-Inverse Document Frequency) model: `movie_tfidf_model`. The TF-IDF model is used to transform the bag-of-words representation of documents into a TF-IDF representation, which reflects the importance of words in the documents relative to the entire corpus.
# - Recall that each document in the corpus is represented as a list of `(token_id, token_count)` tuples.
# - The `id2word=dictionary` parameter specifies the dictionary that maps token IDs to words = The `dictionary` object is used to convert token IDs back to words.

# %% [markdown]
# `gensim.models.LsiModel` initializes an LSI model. LSI is a technique used to reduce the dimensionality of the term-document matrix and to identify patterns in the relationships between terms and documents.
#
# `movie_lsi_model` is an LSI model trained on the TF-IDF-transformed corpus. The model reduces the dimensionality of the term-document matrix and identifies 300 topics.
# - `movie_tfidf_model[corpus]` applies `movie_tfidf_model` to the corpus. The result is a corpus where each document is represented in the TF-IDF format instead of the original bag-of-words format.
# - `num_topics=300`: the model will extract 300 topics

# %% [markdown]
# The **coherence score** is a measure used to evaluate the quality of topics generated by a topic model, such as the LSI (Latent Semantic Indexing) model. It quantifies how interpretable and meaningful the topics are by examining the degree of **semantic similarity between high-scoring words in each topic**.
#
# Semantic Similarity:
#
# The coherence score measures the semantic similarity between words within a topic. Higher coherence scores indicate that the words in a topic are more semantically related, making the topic more interpretable and meaningful.
#
# Types of Coherence Measures:
#
# There are several types of coherence measures, such as `c_v`, `u_mass`, `c_uci`, and `c_npmi`. In the provided code, the `c_v` coherence measure is used, which combines several measures to provide a robust evaluation of topic coherence.
#
# Evaluation Process:
#
# The coherence score is computed by first extracting the top words for each topic. Then, the semantic similarity between these words is calculated using various metrics, such as word co-occurrence in the original texts.
#
# The `c_v` coherence measure combines several metrics to evaluate the coherence of topics. It is based on a sliding window, one-set segmentation of the top words, and an indirect confirmation measure that uses normalized pointwise mutual information (NPMI) and the cosine similarity.
# The scores for `c_v` coherence typically range from 0 to 1, where higher scores indicate better coherence.

# %%
# Define a range of numbers of topics to evaluate
topic_range = range(100, 1000, 100)  # Evaluate from 100 to 1000 topics in steps of 100
coherence_scores = []

# Evaluate coherence scores for different numbers of topics
for num_topics in topic_range:
    # Create the LSI model
    movie_lsi_model = gensim.models.LsiModel(movie_tfidf_model[corpus], id2word=dictionary, num_topics=num_topics)

    # Evaluate the model using topic coherence
    coherence_model_lsi = CoherenceModel(model=movie_lsi_model, texts=movie_plot, dictionary=dictionary, coherence='c_v')
    coherence_lsi = coherence_model_lsi.get_coherence()

    coherence_scores.append(coherence_lsi)
    print(f'Number of Topics: {num_topics}, Coherence Score: {coherence_lsi}')

# Plot the coherence scores
plt.figure(figsize=(10, 6))
plt.plot(topic_range, coherence_scores, marker='o')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score')
plt.title('Coherence Scores for Different Numbers of Topics')
plt.show()

# Find the best number of topics
best_num_topics = topic_range[coherence_scores.index(max(coherence_scores))]
print(f'Best Number of Topics: {best_num_topics}')
# Out:
# Number of Topics: 100, Coherence Score: 0.3313451572177996
# Number of Topics: 200, Coherence Score: 0.3572856646159201
# Number of Topics: 300, Coherence Score: 0.3829927234406231
# Number of Topics: 400, Coherence Score: 0.4003028629942408
# Number of Topics: 500, Coherence Score: 0.41347791789282573
# Number of Topics: 600, Coherence Score: 0.4262823355473101
# Number of Topics: 700, Coherence Score: 0.4412322354943185
# Number of Topics: 800, Coherence Score: 0.44816832626959935
# Number of Topics: 900, Coherence Score: 0.4601824091095656
# Best Number of Topics: 900

# %%
# Define a range of numbers of topics to evaluate
topic_range = range(900, 2101, 300)  # Evaluate from 900 to 2100 topics in steps of 300
coherence_scores = []

# Evaluate coherence scores for different numbers of topics
for num_topics in topic_range:
    # Create the LSI model
    movie_lsi_model = gensim.models.LsiModel(movie_tfidf_model[corpus], id2word=dictionary, num_topics=num_topics)

    # Evaluate the model using topic coherence
    coherence_model_lsi = CoherenceModel(model=movie_lsi_model, texts=movie_plot, dictionary=dictionary, coherence='c_v')
    coherence_lsi = coherence_model_lsi.get_coherence()

    coherence_scores.append(coherence_lsi)
    print(f'Number of Topics: {num_topics}, Coherence Score: {coherence_lsi}')

# Find the best number of topics
best_num_topics = topic_range[coherence_scores.index(max(coherence_scores))]
print(f'Best Number of Topics: {best_num_topics}')
# Out:
# Number of Topics: 900, Coherence Score: 0.46176583267031535
# Number of Topics: 1200, Coherence Score: 0.48546097553323203
# Number of Topics: 1500, Coherence Score: 0.5033112857094264
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 12
#      10 # Evaluate the model using topic coherence
#      11 coherence_model_lsi = CoherenceModel(model=movie_lsi_model, texts=movie_plot, dictionary=dictionary, coherence='c_v')
# ---> 12 coherence_lsi = coherence_model_lsi.get_coherence()
#      14 coherence_scores.append(coherence_lsi)
#      15 print(f'Number of Topics: {num_topics}, Coherence Score: {coherence_lsi}')
#
# File ~/.pyenv/versions/3.10.6/envs/Semantic_Search/lib/python3.10/site-packages/gensim/models/coherencemodel.py:614, in CoherenceModel.get_coherence(self)
#     605 def get_coherence(self):
#     606     """Get coherence value based on pipeline parameters.
#     607
#     608     Returns
#    (...)
#     612
#     613     """
# --> 614     confirmed_measures = self.get_coherence_per_topic()
#     615     return self.aggregate_measures(confirmed_measures)
#
# File ~/.pyenv/versions/3.10.6/envs/Semantic_Search/lib/python3.10/site-packages/gensim/models/coherencemodel.py:574, in CoherenceModel.get_coherence_per_topic(self, segmented_topics, with_std, with_support)
#     572     segmented_topics = measure.seg(self.topics)
#     573 if self._accumulator is None:
# --> 574     self.estimate_probabilities(segmented_topics)
#     576 kwargs = dict(with_std=with_std, with_support=with_support)
#     577 if self.coherence in BOOLEAN_DOCUMENT_BASED or self.coherence == 'c_w2v':
#
# File ~/.pyenv/versions/3.10.6/envs/Semantic_Search/lib/python3.10/site-packages/gensim/models/coherencemodel.py:546, in CoherenceModel.estimate_probabilities(self, segmented_topics)
#     543     if self.coherence == 'c_w2v':
#     544         kwargs['model'] = self.keyed_vectors
# --> 546     self._accumulator = self.measure.prob(**kwargs)
#     548 return self._accumulator
#
# File ~/.pyenv/versions/3.10.6/envs/Semantic_Search/lib/python3.10/site-packages/gensim/topic_coherence/probability_estimation.py:156, in p_boolean_sliding_window(texts, segmented_topics, dictionary, window_size, processes)
#     154     accumulator = ParallelWordOccurrenceAccumulator(processes, top_ids, dictionary)
#     155 logger.info("using %s to estimate probabilities from sliding windows", accumulator)
# --> 156 return accumulator.accumulate(texts, window_size)
#
# File ~/.pyenv/versions/3.10.6/envs/Semantic_Search/lib/python3.10/site-packages/gensim/topic_coherence/text_analysis.py:445, in ParallelWordOccurrenceAccumulator.accumulate(self, texts, window_size)
#     442     logger.warn("stats accumulation interrupted; <= %d documents processed", self._num_docs)
#     443     interrupted = True
# --> 445 accumulators = self.terminate_workers(input_q, output_q, workers, interrupted)
#     446 return self.merge_accumulators(accumulators)
#
# File ~/.pyenv/versions/3.10.6/envs/Semantic_Search/lib/python3.10/site-packages/gensim/topic_coherence/text_analysis.py:522, in ParallelWordOccurrenceAccumulator.terminate_workers(self, input_q, output_q, workers, interrupted)
#     520 accumulators = []
#     521 while len(accumulators) != len(workers):
# --> 522     accumulators.append(output_q.get())
#     523 logger.info("%d accumulators retrieved from output queue", len(accumulators))
#     525 for worker in workers:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/connection.py:221, in _ConnectionBase.recv_bytes(self, maxlength)
#     219 if maxlength is not None and maxlength < 0:
#     220     raise ValueError("negative maxlength")
# --> 221 buf = self._recv_bytes(maxlength)
#     222 if buf is None:
#     223     self._bad_message_length()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/connection.py:419, in Connection._recv_bytes(self, maxsize)
#     418 def _recv_bytes(self, maxsize=None):
# --> 419     buf = self._recv(4)
#     420     size, = struct.unpack("!i", buf.getvalue())
#     421     if size == -1:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/connection.py:384, in Connection._recv(self, size, read)
#     382 remaining = size
#     383 while remaining > 0:
# --> 384     chunk = read(handle, remaining)
#     385     n = len(chunk)
#     386     if n == 0:
#
# KeyboardInterrupt:

# %%
# Create the LSI model with 2000 topics
movie_lsi_model = gensim.models.LsiModel(movie_tfidf_model[corpus], id2word=dictionary, num_topics=2000)

# %%
# Transform the TF-IDF corpus into the LSI space
movie_lsi_corpus = movie_lsi_model[movie_tfidf_model[corpus]]

# Transform the original BoW corpus into the TF-IDF space
movie_tfidf_corpus = movie_tfidf_model[corpus]

# %% [markdown]
# The number of terms in the LSI-transformed corpus corresponds to the number of topics specified when creating the LSI model. However, the `movie_lsi_corpus` itself does not have a direct attribute to get the number of terms. Instead, you can infer the number of terms from the LSI model's `num_topics` attribute, as each document in the LSI corpus is represented by a vector of topic weights.

# %%
print(movie_lsi_model.num_topics)  # Should print the number of topics, e.g., 2000
print(movie_lsi_model.num_terms)   # Should print the number of terms in the dictionary

# Number of terms in the dictionary
num_terms_in_dictionary = len(dictionary)
print(f"Number of terms in dictionary: {num_terms_in_dictionary}")

# Number of topics in the LSI model
num_topics_in_lsi_model = movie_lsi_model.num_topics
print(f"Number of topics in LSI model: {num_topics_in_lsi_model}")

# The number of terms in the LSI-transformed corpus should match the number of topics
num_terms_in_lsi_corpus = num_topics_in_lsi_model
print(f"Number of terms in LSI corpus: {num_terms_in_lsi_corpus}")
# Out:
# 2000
# 39437
# Number of terms in dictionary: 39437
# Number of topics in LSI model: 2000
# Number of terms in LSI corpus: 2000

# %% [markdown]
# The following code serializes the TF-IDF-transformed corpus and stores it in a file named `movie_tfidf_model_mm`. This allows for easy retrieval of the transformed corpus in the future without needing to recompute the TF-IDF transformation. The serialized file can be loaded back into memory using `gensim.corpora.MmCorpus` when needed.

# %%
# #Serialize and Store the corpus locally for easy retrival whenever required.
gensim.corpora.MmCorpus.serialize('movie_tfidf_model_mm', movie_tfidf_model[corpus])
gensim.corpora.MmCorpus.serialize('movie_lsi_model_mm',movie_lsi_model[movie_tfidf_model[corpus]])

# %%
#Load the indexed corpus
movie_tfidf_corpus = gensim.corpora.MmCorpus('movie_tfidf_model_mm')
movie_lsi_corpus = gensim.corpora.MmCorpus('movie_lsi_model_mm')

print(movie_tfidf_corpus)
print(movie_lsi_corpus)
# Out:
# MmCorpus(34886 documents, 39437 features, 3590214 non-zero entries)
# MmCorpus(34886 documents, 2000 features, 69771991 non-zero entries)

# %% [markdown]
# `num_docs` attribute represents the number of documents in the corpus that the TF-IDF model was trained on.
#
# `num_nnz` attribute stands for "number of non-zero elements" and represents the total number of non-zero entries in the TF-IDF matrix. In other words, it counts the total number of (document, term) pairs that have a non-zero TF-IDF score. This gives an indication of the sparsity of the TF-IDF matrix.

# %%
print(movie_tfidf_model.num_docs)
print(movie_tfidf_model.num_nnz)

# Number of terms in the TF-IDF model
num_terms = len(dictionary)
print(num_terms)
# Out:
# 34886
# 3590214
# 39437

# %% [markdown]
# `num_topics` attribute represents the number of topics that the LSI model has been trained to identify. We have set it to 300.
#
# `num_terms` attribute represents the number of **unique terms (words)** in the dictionary that the **LSI model** uses. It corresponds to the size of the vocabulary that the model has been trained on. The terms are the unique words that appear in the corpus and are used to construct the topics.
#
# However, `num_terms` attribute for a **corpus** typically refers to the **number of dimensions in the vector space**, which in the case of LSI, corresponds to the **number of topics** (dimensions) the documents are projected onto.
#
# Typically, the number of terms in the LSI corpus should match the number of topics in the LSI model. Given that you have set num_topics=300 when creating the LSI model, the movie_lsi_corpus should have 300 dimensions (topics). If you are seeing 100 terms, it might be due to a specific slicing or filtering applied to the corpus.

# %%
print(movie_lsi_model.num_topics)
print(movie_lsi_model.num_terms)

#print(movie_lsi_corpus.num_topics) #'MmCorpus' object has no attribute 'num_topics'
print(movie_lsi_corpus.num_terms)
# Out:
# 2000
# 39437
# 2000

# %% [markdown]
# `movie_index` is a **similarity index** that allows for efficient computation of **similarities between documents in the LSI-transformed corpus**. This index can be used to find documents that are similar to a given query document by **comparing their LSI representations**.
# - The `MatrixSimilarity` class is used to compute similarities between documents in a corpus.
# - `movie_lsi_corpus` is expected to be the corpus transformed by the LSI model, where each document is represented in the LSI space.
# - `num_features=movie_lsi_corpus.num_terms` specifies the number of features (terms) in the LSI space. `movie_lsi_corpus.num_terms` returns the number of terms in the LSI-transformed corpus.

# %%
#Load the MatrixSimilarity
from gensim.similarities import MatrixSimilarity

movie_index = MatrixSimilarity(movie_lsi_corpus, num_features = movie_lsi_corpus.num_terms)

# %%
# #Load the MatrixSimilarity
# from gensim.similarities import MatrixSimilarity

# movie_index = MatrixSimilarity(movie_lsi_corpus, num_features = 300)

# %% [markdown]
# The `MatrixSimilarity` object creates **a matrix where each row corresponds to a document vector in the LSI space**. This matrix is used to compute similarities between documents.
#
# Once the index is created, you can use it to compute similarities between **a query document** and **all documents** in the corpus. The `MatrixSimilarity` object uses **cosine similarity** to measure the similarity between the query document and each document in the corpus.
#
# Below `query_lsi` is a query document converted by `dictionary.doc2bow(["example", "query", "text"])` into the bag-of-words (BoW) format, which represents the document as a list of `(token_id, token_count)` tuples. The result is an argument to the `movie_tfidf_model`, which converts into a TF-IDF representation. Finally, `movie_lsi_model` is applied to it, to represent the **query document as a vector of topic weights in the LSI space**.
# In summary, `query_lsi` is the LSI-transformed representation of the query document. It is a vector of topic weights obtained by transforming the query document through the TF-IDF model and then the LSI model.
#
# `sims` stores the **similarity scores**. It is a list where each element represents the similarity score between the query document and a document in the corpus. The scores are typically in the range [0, 1], where 1 indicates identical documents and 0 indicates no similarity.

# %%
# Example query document (in LSI space)
query_lsi = movie_lsi_model[movie_tfidf_model[dictionary.doc2bow(["example", "query", "text"])]]

# Compute similarities of the query document to all documents in the corpus
sims = movie_index[query_lsi]

# Print the first 5 similarities
display(list(enumerate(sims))[:5])
# Out:
# [(0, 0.00820413),
#  (1, -0.012667026),
#  (2, 0.018518638),
#  (3, 0.015255535),
#  (4, 0.02237332)]

# %%
# Find the highest similarity score
max_similarity = np.max(sims)

# Find the index of the document with the highest similarity score
max_similarity_index = np.argmax(sims)

# Print the highest similarity score and the corresponding document index
print(f"Highest similarity score: {max_similarity}")
print(f"Document index with highest similarity: {max_similarity_index}")
# Out:
# Highest similarity score: 0.39336884021759033
# Document index with highest similarity: 10747

# %%
query_lsi = movie_lsi_model[movie_tfidf_model[dictionary.doc2bow(["love", "affair", "hate"])]]
sims = movie_index[query_lsi]
max_similarity = np.max(sims)
max_similarity_index = np.argmax(sims)
print(f"Highest similarity score: {max_similarity}")
print(f"Document index with highest similarity: {max_similarity_index}")
# Out:
# Highest similarity score: 0.615317702293396
# Document index with highest similarity: 1677

# %%
query_lsi = movie_lsi_model[movie_tfidf_model[dictionary.doc2bow(["dinosaur", "adventure"])]]
sims = movie_index[query_lsi]
max_similarity = np.max(sims)
max_similarity_index = np.argmax(sims)
print(f"Highest similarity score: {max_similarity}")
print(f"Document index with highest similarity: {max_similarity_index}")
# Out:
# Highest similarity score: 0.5738294720649719
# Document index with highest similarity: 34882

# %% [markdown]
# ## Semantic Search¶

# %% [markdown]
# With the index of movies initialized and loaded, we use it to find similar movies.
#
# We will input a search query and the model will return relevant movie titles with “Relevance %” which is the similarity score. The higher the similarity score, the more similar the query to the document at the given index.
#
# Below is the helper function to search the index, sort and return the results.

# %% [markdown]
# How the helper function works:
#
# 1. The search term is tokenized and converted into a bag-of-words (BoW) representation using the `dictionary`.
# 2. The BoW representation of the query, `query_bow`, is transformed into the TF-IDF space using the `movie_tfidf_model`.
# 3. The TF-IDF representation of the query, `query_lsi`,  is further transformed into the LSI space using the movie_lsi_model.
# 4. The number of best matches to retrieve is set to 5.
# 5. The similarity scores between the query document and all documents in the LSI-transformed corpus are computed using the `movie_index`. The result is stored in `movies_list`,  a list of tuples, where each tuple contains a document index and its similarity score. For example, a tuple might look like `(0, 0.75)`, where `0` is the document index and `0.75` is the similarity score.
# 6. The list of movies is sorted in descending order based on the similarity scores (relevance): `movies_list.sort(key=itemgetter(1), reverse=True)`
# - `itemgetter(1)` creates a function that retrieves the second element (index 1) of a tuple. In this context, it retrieves the similarity score from each tuple in `movies_list`.
# 7. The function iterates over the sorted list of movies and creates a list of dictionaries containing the relevance, movie title, and movie plot for the top 5 matches. `round((movie[1] * 100), 2)` computes the **relevance score as a percentage** by multiplying the **similarity score** by 100 and rounding it to two decimal places.
# - `movie` is a tuple from the `movies_list`, where `movie[0]` is the index of the movie in the DataFrame, and `movie[1]` is the similarity score.
# - `df_movies['title']` accesses the 'title' column of the DataFrame, and `[movie[0]]` selects the specific row corresponding to the movie index.

# %% [markdown]
# The indexes in `movies_list` are the same as in `df_movies`. Here's why:
#
# - Creating the Corpus: The original corpus (`corpus`) is created from the movie plots in `df_movies`. Each document in the corpus corresponds to a row in `df_movies`.
#
# - Transforming the Corpus: The corpus is transformed into the TF-IDF space and then into the LSI space. The document order remains the same throughout these transformations.
#
# - Computing Similarities: When computing similarities using `movie_index`, the similarity scores are computed for each document in the LSI-transformed corpus. The document indexes in `movies_list` correspond to the original document indexes in `df_movies`.
#
# - Retrieving Movie Information: The function `search_similar_movies` uses these indexes to retrieve the movie titles and plots from `df_movies`. For example, `df_movies['title'][movie[0]]` retrieves the title of the movie corresponding to the index `movie[0]`.

# %%
from operator import itemgetter

def search_similar_movies(search_term):

    query_bow = dictionary.doc2bow(tokenizer(search_term))
    query_tfidf = movie_tfidf_model[query_bow]
    query_lsi = movie_lsi_model[query_tfidf]

    movie_index.num_best = 20

    movies_list = movie_index[query_lsi]

    movies_list.sort(key=itemgetter(1), reverse=True)
    movie_names = []

    for j, movie in enumerate(movies_list):

        movie_names.append (
            {
                'Relevance': round((movie[1] * 100),2),
                'Movie Title': df_movies['Title'][movie[0]],
                'Movie Plot': df_movies['Plot'][movie[0]]
            }

        )
        if j == (movie_index.num_best-1):
            break

    return pd.DataFrame(movie_names, columns=['Relevance','Movie Title','Movie Plot'])

# %%
search_similar_movies('crime and drugs')
# Out:
#     Relevance                           Movie Title  \
# 0       54.41                                  Rush
# 1       52.58                She Shoulda Said 'No'!
# 2       50.47                      Port of New York
# 3       48.82                    Dallas Buyers Club
# 4       48.22       Snake Eater II: The Drug Buster
# 5       43.54                           Clay Pigeon
# 6       43.49                    The Amsterdam Kill
# 7       42.86                         Dum Maaro Dum
# 8       42.12               Mad Dogs and Englishmen
# 9       40.25  Yaji and Kita: The Midnight Pilgrims
# 10      40.22                 For the Love of Money
# 11      39.60                               Traffic
# 12      39.48                       Veronica Guerin
# 13      38.57                            Essex Boys
# 14      38.07                       Angels' Brigade
# 15      37.77                 Last Exit to Brooklyn
# 16      37.13                            Cedar Boys
# 17      37.06                              The Fake
# 18      36.89                      Snow in Paradise
# 19      36.26                       New Best Friend
#
#                                            Movie Plot
# 0   In Texas, seasoned undercover narcotics police...
# 1   Leeds' character is "Anne Lester", a young orp...
# 2   The film tells the story of a two federal agen...
# 3   In July 1985, Dallas electrician and rodeo cow...
# 4   In this installment of the series Jack Kelly t...
# 5   A Vietnam War veteran (Stern) has been using i...
# 6   Former DEA Agent Quinlan, removed from the for...
# 7   The film starts with a footballer, Lorry (Prat...
# 8   Antonia Dyer is a well-to-do Englishwoman with...
# 9   Yaji and Kita are two men who live in Edo. The...
# 10  In Tel Aviv, 1973, young Izek is raised in a s...
# 11  In Mexico, police officer Javier Rodriguez (de...
# 12  Veronica Guerin, a crime reporter for the Sund...
# 13  The film is based loosely around events in Dec...
# 14  The movie focuses on seven women who decide to...
# 15  A group of prostitutes, union workers, and dra...
# 16  Tarek (Les Chantery) a Lebanese-Australian, li...
# 17  An M.P. pressures his daughter to marry an ari...
# 18  Petty criminal Dave lives in London, high on c...
# 19  A North Carolina sheriff (Taye Diggs) investig...

# %%
from operator import itemgetter
import pandas as pd
from IPython.display import display

def search_similar_movies_2(search_term):
    query_bow = dictionary.doc2bow(tokenizer(search_term))
    query_tfidf = movie_tfidf_model[query_bow]
    query_lsi = movie_lsi_model[query_tfidf]
    
    movies_list = movie_index[query_lsi]
    movies_list.sort(key=itemgetter(1), reverse=True)
    
    results_per_page = 10
    start_index = 0
    
    # Function to truncate the plot to first 20 words
    def truncate_plot(plot_text):
        words = plot_text.split()
        if len(words) <= 10:
            return plot_text
        return ' '.join(words[:10]) + '...'
    
    while start_index < len(movies_list):
        movie_names = []
        
        for j, movie in enumerate(movies_list[start_index:start_index + results_per_page]):
            movie_names.append({
                'Relevance': round((movie[1] * 100), 2),
                'Movie Title': df_movies['Title'][movie[0]],
                'Movie Plot': truncate_plot(df_movies['Plot'][movie[0]])
            })
        
        results_df = pd.DataFrame(movie_names, columns=['Relevance','Movie Title','Movie Plot'])
        
        # Improved display configuration
        pd.set_option('display.max_colwidth', None)  # Don't truncate column contents
        pd.set_option('display.expand_frame_repr', False)  # Try to show all columns in one row
        pd.set_option('display.max_rows', 10)  # Show only 10 rows max
        pd.set_option('display.precision', 2)  # Show 2 decimal places for floats
        pd.set_option('display.colheader_justify', 'left')  # Left-align column headers
        
        # Add a title/header before showing results
        print("\n" + "="*80)
        print(f"SEARCH RESULTS FOR: '{search_term}' (showing {len(results_df)} of {len(movies_list)} matches)")
        print("="*80 + "\n")

        styled_df = results_df.style.background_gradient(
        subset=['Relevance'], cmap='Blues', high=0.5
        ).set_properties(**{'text-align': 'left'})

        display(styled_df)
        
        # # Display the DataFrame with improved formatting
        # print(results_df.to_string(index=False))  # Remove index column for cleaner display
        
        user_input = input("Did you find the movie you were looking for? (yes/no): ").strip().lower()
        
        if user_input == 'yes':
            return results_df
        else:
            results_per_page += 5
            continue
    
    print("No more results found.")
    return None

# %%
search_similar_movies_2('sex rock love')
# Out:
# ================================================================================
# SEARCH RESULTS FOR: 'sex rock love' (showing 10 of 20 matches)
# ================================================================================
# <style type="text/css">
# #T_5a691_row0_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_5a691_row0_col1, #T_5a691_row0_col2, #T_5a691_row1_col1, #T_5a691_row1_col2, #T_5a691_row2_col1, #T_5a691_row2_col2, #T_5a691_row3_col1, #T_5a691_row3_col2, #T_5a691_row4_col1, #T_5a691_row4_col2, #T_5a691_row5_col1, #T_5a691_row5_col2, #T_5a691_row6_col1, #T_5a691_row6_col2, #T_5a691_row7_col1, #T_5a691_row7_col2, #T_5a691_row8_col1, #T_5a691_row8_col2, #T_5a691_row9_col1, #T_5a691_row9_col2 {
#   text-align: left;
# }
# #T_5a691_row1_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_5a691_row2_col0 {
#   background-color: #bed8ec;
#   color: #000000;
#   text-align: left;
# }
# #T_5a691_row3_col0 {
#   background-color: #c7dbef;
#   color: #000000;
#   text-align: left;
# }
# #T_5a691_row4_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
#   text-align: left;
# }
# #T_5a691_row5_col0 {
#   background-color: #deebf7;
#   color: #000000;
#   text-align: left;
# }
# #T_5a691_row6_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
#   text-align: left;
# }
# #T_5a691_row7_col0 {
#   background-color: #eef5fc;
#   color: #000000;
#   text-align: left;
# }
# #T_5a691_row8_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
#   text-align: left;
# }
# #T_5a691_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: left;
# }
# </style>
# <table id="T_5a691">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a691_level0_col0" class="col_heading level0 col0" >Relevance</th>
#       <th id="T_5a691_level0_col1" class="col_heading level0 col1" >Movie Title</th>
#       <th id="T_5a691_level0_col2" class="col_heading level0 col2" >Movie Plot</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a691_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a691_row0_col0" class="data row0 col0" >54.180000</td>
#       <td id="T_5a691_row0_col1" class="data row0 col1" >Tenacious D in The Pick of Destiny</td>
#       <td id="T_5a691_row0_col2" class="data row0 col2" >As a young man, JB (Jack Black) leaves his religious...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a691_row1_col0" class="data row1 col0" >50.430000</td>
#       <td id="T_5a691_row1_col1" class="data row1 col1" >Shorts</td>
#       <td id="T_5a691_row1_col2" class="data row1 col2" >Toby "Toe" Thompson (Jimmy Bennett) a 11-year old is bullied...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a691_row2_col0" class="data row2 col0" >43.670000</td>
#       <td id="T_5a691_row2_col1" class="data row2 col1" >Light of Day</td>
#       <td id="T_5a691_row2_col2" class="data row2 col2" >Fox and Jett play a brother and sister who are...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5a691_row3_col0" class="data row3 col0" >42.910000</td>
#       <td id="T_5a691_row3_col1" class="data row3 col1" >After Sex</td>
#       <td id="T_5a691_row3_col2" class="data row3 col2" >Christopher and Leslie are a couple in their mid to...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5a691_row4_col0" class="data row4 col0" >41.460000</td>
#       <td id="T_5a691_row4_col1" class="data row4 col1" >Curucu, Beast of the Amazon</td>
#       <td id="T_5a691_row4_col2" class="data row4 col2" >Plantation owner Rock Dean (Bromfield) travels up the Amazon River...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5a691_row5_col0" class="data row5 col0" >39.740000</td>
#       <td id="T_5a691_row5_col1" class="data row5 col1" >GoBots: Battle of the Rock Lords</td>
#       <td id="T_5a691_row5_col2" class="data row5 col2" >The Guardian Gobots are continuing their work on rebuilding their...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5a691_row6_col0" class="data row6 col0" >38.440000</td>
#       <td id="T_5a691_row6_col1" class="data row6 col1" >Mirugam</td>
#       <td id="T_5a691_row6_col2" class="data row6 col2" >The story is set in a village near Ramnad. The...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5a691_row7_col0" class="data row7 col0" >37.570000</td>
#       <td id="T_5a691_row7_col1" class="data row7 col1" >The Night of the White Pants</td>
#       <td id="T_5a691_row7_col2" class="data row7 col2" >Max Hagan, a Texas oil tycoon, is going through a...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5a691_row8_col0" class="data row8 col0" >36.670000</td>
#       <td id="T_5a691_row8_col1" class="data row8 col1" >To Beep or Not to Beep</td>
#       <td id="T_5a691_row8_col2" class="data row8 col2" >Introduction: The opening scene shows Wile E. Coyote reading a...</td>
#     </tr>
#     <tr>
#       <th id="T_5a691_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5a691_row9_col0" class="data row9 col0" >36.300000</td>
#       <td id="T_5a691_row9_col1" class="data row9 col1" >Beneath the Valley of the Ultra-Vixens</td>
#       <td id="T_5a691_row9_col2" class="data row9 col2" >The movie starts with introductions to the people of Small...</td>
#     </tr>
#   </tbody>
# </table>
# Did you find the movie you were looking for? (yes/no):  yes
#    Relevance Movie Title                             Movie Plot
# 0  54.18          Tenacious D in The Pick of Destiny                As a young man, JB (Jack Black) leaves his religious...
# 1  50.43                                      Shorts        Toby "Toe" Thompson (Jimmy Bennett) a 11-year old is bullied...
# 2  43.67                                Light of Day                      Fox and Jett play a brother and sister who are...
# 3  42.91                                   After Sex                 Christopher and Leslie are a couple in their mid to...
# 4  41.46                 Curucu, Beast of the Amazon  Plantation owner Rock Dean (Bromfield) travels up the Amazon River...
# 5  39.74            GoBots: Battle of the Rock Lords   The Guardian Gobots are continuing their work on rebuilding their...
# 6  38.44                                     Mirugam                      The story is set in a village near Ramnad. The...
# 7  37.57                The Night of the White Pants                   Max Hagan, a Texas oil tycoon, is going through a...
# 8  36.67                      To Beep or Not to Beep      Introduction: The opening scene shows Wile E. Coyote reading a...
# 9  36.30      Beneath the Valley of the Ultra-Vixens          The movie starts with introductions to the people of Small...

# %%
from operator import itemgetter
import pandas as pd

def search_similar_movies_3(search_term):
    query_bow = dictionary.doc2bow(tokenizer(search_term))
    query_tfidf = movie_tfidf_model[query_bow]
    query_lsi = movie_lsi_model[query_tfidf]
    
    movies_list = movie_index[query_lsi]
    movies_list.sort(key=itemgetter(1), reverse=True)
    
    results_per_page = 10
    start_index = 1
    
    # Function to truncate the plot to first 20 words
    def truncate_plot(plot_text):
        words = plot_text.split()
        if len(words) <= 10:
            return plot_text
        return ' '.join(words[:10]) + '...'
    
    while start_index < len(movies_list):
        movie_names = []
        
        # Store original movie data for later full plot display
        current_page_movies = []
        
        for j, movie in enumerate(movies_list[start_index:start_index + results_per_page]):
            movie_index_in_df = movie[0]
            movie_title = df_movies['Title'][movie_index_in_df]
            movie_plot = df_movies['Plot'][movie_index_in_df]
            
            movie_names.append({
                'Index': j,  # Add display index for selection
                'Relevance': round((movie[1] * 100), 2),
                'Movie Title': movie_title,
                'Movie Plot': truncate_plot(movie_plot)
            })
            
            # Store complete information
            current_page_movies.append({
                'Index': movie_index_in_df,
                'Title': movie_title,
                'Plot': movie_plot,
                'Relevance': round((movie[1] * 100), 2)
            })
        
        results_df = pd.DataFrame(movie_names, columns=['Index', 'Relevance', 'Movie Title', 'Movie Plot'])
        
        # Set display options
        pd.set_option('display.max_colwidth', None)  # Don't truncate column contents
        pd.set_option('display.expand_frame_repr', False)  # Try to show all columns in one row
        pd.set_option('display.max_rows', 10)  # Show only 10 rows max
        pd.set_option('display.precision', 2)  # Show 2 decimal places for floats
        pd.set_option('display.colheader_justify', 'right')  # Left-align column headers

        
        
        print("\n" + "="*80)
        print(f"SEARCH RESULTS FOR: '{search_term}' (Page {start_index//results_per_page + 1})")
        print("="*80)

        styled_df = results_df.style.background_gradient(
        subset=['Relevance'], cmap='Blues', high=0.5
        ).set_properties(**{'text-align': 'left'})
        display(styled_df)
        
        # Ask user if they found the movie or want to see full plot
        user_input = input("\nDid you find the movie you were looking for? (yes/no) or enter a movie index number to see full plot: ").strip().lower()
        
        # Check if user entered a number
        try:
            movie_idx = int(user_input)
            if 0 <= movie_idx < len(current_page_movies):
                # Display full details for the selected movie
                selected_movie = current_page_movies[movie_idx]
                print("\n" + "="*80)
                print(f"FULL DETAILS FOR: {selected_movie['Title']}")
                print(f"Relevance Score: {selected_movie['Relevance']}%")
                print("="*80)
                print("\nPLOT SUMMARY:")
                print(selected_movie['Plot'])
                print("\n" + "="*80)
                
                # Ask if they want to continue searching or return this movie
                continue_input = input("\nIs this the movie you were looking for? (yes/no): ").strip().lower()
                if continue_input == 'yes':
                    selected_movie['Relevance'] = f"{selected_movie['Relevance']:.2f}%"
                    return pd.DataFrame([selected_movie],columns=['Index', 'Relevance', 'Title', 'Plot'])
                # If no, continue with the loop and show the same page again
                continue
            else:
                print("Invalid movie index. Please try again.")
                continue
        except ValueError:
            # Not a number, process as yes/no
            pass
        
        if user_input == 'yes':
            # Ask which movie they want to return
            while True:
                try:
                    selection = int(input("Enter the index of the movie you want to select: "))
                    if 0 <= selection < len(current_page_movies):
                        current_page_movies[selection]['Relevance'] = f"{current_page_movies[selection]['Relevance']:.2f}%"
                        return pd.DataFrame([current_page_movies[selection]],columns=['Index', 'Relevance', 'Title', 'Plot'])
                    else:
                        print("Invalid index. Please try again.")
                except ValueError:
                    print("Please enter a valid number.")
        elif user_input == 'no':
            
            results_per_page += 5
        else:
            print("Invalid input. Please enter 'yes', 'no', or a movie index.")
    
    print("No more results found.")
    return None

# %%
search_similar_movies_3('toys disney woody buzz')
# Out:
# ================================================================================
# SEARCH RESULTS FOR: 'toys disney woody buzz' (Page 1)
# ================================================================================
# <style type="text/css">
# #T_3d5f1_row0_col0, #T_3d5f1_row0_col2, #T_3d5f1_row0_col3, #T_3d5f1_row1_col0, #T_3d5f1_row1_col2, #T_3d5f1_row1_col3, #T_3d5f1_row2_col0, #T_3d5f1_row2_col2, #T_3d5f1_row2_col3, #T_3d5f1_row3_col0, #T_3d5f1_row3_col2, #T_3d5f1_row3_col3, #T_3d5f1_row4_col0, #T_3d5f1_row4_col2, #T_3d5f1_row4_col3, #T_3d5f1_row5_col0, #T_3d5f1_row5_col2, #T_3d5f1_row5_col3, #T_3d5f1_row6_col0, #T_3d5f1_row6_col2, #T_3d5f1_row6_col3, #T_3d5f1_row7_col0, #T_3d5f1_row7_col2, #T_3d5f1_row7_col3, #T_3d5f1_row8_col0, #T_3d5f1_row8_col2, #T_3d5f1_row8_col3, #T_3d5f1_row9_col0, #T_3d5f1_row9_col2, #T_3d5f1_row9_col3 {
#   text-align: left;
# }
# #T_3d5f1_row0_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_3d5f1_row1_col1 {
#   background-color: #4292c6;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_3d5f1_row2_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_3d5f1_row3_col1 {
#   background-color: #8abfdd;
#   color: #000000;
#   text-align: left;
# }
# #T_3d5f1_row4_col1 {
#   background-color: #c7dbef;
#   color: #000000;
#   text-align: left;
# }
# #T_3d5f1_row5_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
#   text-align: left;
# }
# #T_3d5f1_row6_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
#   text-align: left;
# }
# #T_3d5f1_row7_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
#   text-align: left;
# }
# #T_3d5f1_row8_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
#   text-align: left;
# }
# #T_3d5f1_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: left;
# }
# </style>
# <table id="T_3d5f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d5f1_level0_col0" class="col_heading level0 col0" >Index</th>
#       <th id="T_3d5f1_level0_col1" class="col_heading level0 col1" >Relevance</th>
#       <th id="T_3d5f1_level0_col2" class="col_heading level0 col2" >Movie Title</th>
#       <th id="T_3d5f1_level0_col3" class="col_heading level0 col3" >Movie Plot</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d5f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d5f1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3d5f1_row0_col1" class="data row0 col1" >90.990000</td>
#       <td id="T_3d5f1_row0_col2" class="data row0 col2" >Puny Express</td>
#       <td id="T_3d5f1_row0_col3" class="data row0 col3" >In the Old West, Cowboy Woody comes to town and...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d5f1_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_3d5f1_row1_col1" class="data row1 col1" >89.220000</td>
#       <td id="T_3d5f1_row1_col2" class="data row1 col2" >Toy Story</td>
#       <td id="T_3d5f1_row1_col3" class="data row1 col3" >In a world where toys are living things who pretend...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d5f1_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_3d5f1_row2_col1" class="data row2 col1" >88.720000</td>
#       <td id="T_3d5f1_row2_col2" class="data row2 col2" >Toy Story 2</td>
#       <td id="T_3d5f1_row2_col3" class="data row2 col3" >Andy prepares to go to cowboy camp with Woody, but...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d5f1_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_3d5f1_row3_col1" class="data row3 col1" >81.090000</td>
#       <td id="T_3d5f1_row3_col2" class="data row3 col2" >Toy Story 3</td>
#       <td id="T_3d5f1_row3_col3" class="data row3 col3" >Seventeen-year-old Andy[11] is about to leave for college, and his...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d5f1_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_3d5f1_row4_col1" class="data row4 col1" >74.010000</td>
#       <td id="T_3d5f1_row4_col2" class="data row4 col2" >The Barber of Seville</td>
#       <td id="T_3d5f1_row4_col3" class="data row4 col3" >Woody arrives at "Tony Figaro's" barber shop in hopes of...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d5f1_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_3d5f1_row5_col1" class="data row5 col1" >71.700000</td>
#       <td id="T_3d5f1_row5_col2" class="data row5 col2" >Girl from Havana</td>
#       <td id="T_3d5f1_row5_col3" class="data row5 col3" >Woody and Tex, a pair of American oilmen working in...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d5f1_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_3d5f1_row6_col1" class="data row6 col1" >70.230000</td>
#       <td id="T_3d5f1_row6_col2" class="data row6 col2" >Nebraska</td>
#       <td id="T_3d5f1_row6_col3" class="data row6 col3" >In Billings, Montana, a police officer arrives and discovers Woody...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d5f1_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_3d5f1_row7_col1" class="data row7 col1" >66.150000</td>
#       <td id="T_3d5f1_row7_col2" class="data row7 col2" >Condorman</td>
#       <td id="T_3d5f1_row7_col3" class="data row7 col3" >Woodrow "Woody" Wilkins is an imaginative, yet eccentric, comic book...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d5f1_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_3d5f1_row8_col1" class="data row8 col1" >64.480000</td>
#       <td id="T_3d5f1_row8_col2" class="data row8 col2" >Bio Zombie</td>
#       <td id="T_3d5f1_row8_col3" class="data row8 col3" >Woody Invincible and Crazy Bee are two young men selling...</td>
#     </tr>
#     <tr>
#       <th id="T_3d5f1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d5f1_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_3d5f1_row9_col1" class="data row9 col1" >63.830000</td>
#       <td id="T_3d5f1_row9_col2" class="data row9 col2" >LUV</td>
#       <td id="T_3d5f1_row9_col3" class="data row9 col3" >The film begins with Woody Watson (Michael Rainey Jr.) having...</td>
#     </tr>
#   </tbody>
# </table>
# Did you find the movie you were looking for? (yes/no) or enter a movie index number to see full plot:  2
# ================================================================================
# FULL DETAILS FOR: Toy Story 2
# Relevance Score: 88.72%
# ================================================================================
#
# PLOT SUMMARY:
# Andy prepares to go to cowboy camp with Woody, but while playing with Woody and Buzz, he accidentally tears Woody's arm. Andy's mom puts Woody on a shelf, and Andy leaves without Woody. The next day, Woody finds that Wheezy has been shelved for months due to a broken squeaker. Andy's mother puts Wheezy in a yard sale, but Woody rescues him, only to be stolen by a greedy toy collector, who takes him to his apartment. Buzz Lightyear and the rest of Andy's toys identify the thief from a commercial to be Al McWhiggin, the owner of Al's Toy Barn. Buzz, Hamm, Mr. Potato Head, Slinky Dog, and Rex set out to rescue Woody.
# At Al's apartment, Woody learns that he is based on a 1950s[9] television show called Woody's Roundup, and that along with the other Roundup toys – Jessie, Bullseye, and Stinky Pete the Prospector – he is set to be sold to a toy museum in Tokyo, Japan. While the others are excited about going, Woody intends to return home to Andy. Stinky Pete explains that the museum is only interested in the collection if it is complete, and without Woody, they will be returned to storage.
# When Woody's arm is torn off completely, Woody attempts to retrieve it and escape, but is foiled when Al's television set turns on, and blames Jessie when he finds the TV remote in front of her. The next morning, Woody's arm is fixed by a toy repair specialist, and he learns that Jessie once belonged to Emily, who eventually outgrew her and gave her away. Stinky Pete warns him that the same fate awaits him when Andy grows up, whereas he will last forever in the museum. Woody decides to stay, now believing that all toys will eventually get discarded by their owners.
# Meanwhile, Buzz and the other toys reach Al's Toy Barn. While searching for Woody, Buzz is imprisoned by a Utility Belt Buzz, who believes that Buzz is a rogue space ranger; he joins the other toys, who mistake him for Andy's Buzz. After discovering Al's plan, they go to his apartment, while Andy's Buzz escapes and pursues them, accidentally freeing an Emperor Zurg toy, who follows him with the intent of destroying him. After the toys find Woody, Buzz rejoins them and proves that he is Andy's Buzz, but Woody refuses to go home.
# Buzz reminds Woody that a toy's true purpose is to be played with, which he would never experience in a museum. After seeing a boy play with him on television, Woody realizes that Buzz was right, and asks the Roundup gang to come home with him and Andy's toys. However, Stinky Pete declines and stops them from leaving, revealing that he wants to go to the museum to be appreciated forever, having never been sold or played with. He was also the one responsible for foiling Woody's earlier escape attempt and framing Jessie for it. Al then returns, takes the gang in a suitcase and leaves for the airport.
# Andy's toys pursue Al, but are caught by Zurg, who battles Utility Belt Buzz, until Rex inadvertently knocks him off the elevator. Utility Belt Buzz then chooses to remain behind with Zurg, who has revealed himself as Buzz's father. Accompanied by three toy Aliens, Andy's toys steal a Pizza Planet delivery truck and follow Al to the airport, where they enter the baggage handling system and find the suitcase. Stinky Pete rips Woody's arm during a struggle, but Andy's toys stuff him into a little girl's backpack. They free Bullseye, only for Jessie to end up on the plane bound for Japan. Assisted by Buzz and Bullseye, Woody frees Jessie, and the toys find their way home.
# When Andy returns from camp, he accepts Jessie, Bullseye, and the Aliens as his new toys, thinking that his mother bought them and repairs Woody's torn arm. Al's business has suffered due to him failing to sell the Roundup gang, while Wheezy's squeaker has also been fixed. Woody tells Buzz that he is no longer worried about Andy outgrowing him because, when he eventually does, they will still have each other for company.
#
# ================================================================================
# Is this the movie you were looking for? (yes/no):  yes
#    Index Relevance        Title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Plot
# 0  13574    88.72%  Toy Story 2  Andy prepares to go to cowboy camp with Woody, but while playing with Woody and Buzz, he accidentally tears Woody's arm. Andy's mom puts Woody on a shelf, and Andy leaves without Woody. The next day, Woody finds that Wheezy has been shelved for months due to a broken squeaker. Andy's mother puts Wheezy in a yard sale, but Woody rescues him, only to be stolen by a greedy toy collector, who takes him to his apartment. Buzz Lightyear and the rest of Andy's toys identify the thief from a commercial to be Al McWhiggin, the owner of Al's Toy Barn. Buzz, Hamm, Mr. Potato Head, Slinky Dog, and Rex set out to rescue Woody.\r\nAt Al's apartment, Woody learns that he is based on a 1950s[9] television show called Woody's Roundup, and that along with the other Roundup toys – Jessie, Bullseye, and Stinky Pete the Prospector – he is set to be sold to a toy museum in Tokyo, Japan. While the others are excited about going, Woody intends to return home to Andy. Stinky Pete explains that the museum is only interested in the collection if it is complete, and without Woody, they will be returned to storage.\r\nWhen Woody's arm is torn off completely, Woody attempts to retrieve it and escape, but is foiled when Al's television set turns on, and blames Jessie when he finds the TV remote in front of her. The next morning, Woody's arm is fixed by a toy repair specialist, and he learns that Jessie once belonged to Emily, who eventually outgrew her and gave her away. Stinky Pete warns him that the same fate awaits him when Andy grows up, whereas he will last forever in the museum. Woody decides to stay, now believing that all toys will eventually get discarded by their owners.\r\nMeanwhile, Buzz and the other toys reach Al's Toy Barn. While searching for Woody, Buzz is imprisoned by a Utility Belt Buzz, who believes that Buzz is a rogue space ranger; he joins the other toys, who mistake him for Andy's Buzz. After discovering Al's plan, they go to his apartment, while Andy's Buzz escapes and pursues them, accidentally freeing an Emperor Zurg toy, who follows him with the intent of destroying him. After the toys find Woody, Buzz rejoins them and proves that he is Andy's Buzz, but Woody refuses to go home.\r\nBuzz reminds Woody that a toy's true purpose is to be played with, which he would never experience in a museum. After seeing a boy play with him on television, Woody realizes that Buzz was right, and asks the Roundup gang to come home with him and Andy's toys. However, Stinky Pete declines and stops them from leaving, revealing that he wants to go to the museum to be appreciated forever, having never been sold or played with. He was also the one responsible for foiling Woody's earlier escape attempt and framing Jessie for it. Al then returns, takes the gang in a suitcase and leaves for the airport.\r\nAndy's toys pursue Al, but are caught by Zurg, who battles Utility Belt Buzz, until Rex inadvertently knocks him off the elevator. Utility Belt Buzz then chooses to remain behind with Zurg, who has revealed himself as Buzz's father. Accompanied by three toy Aliens, Andy's toys steal a Pizza Planet delivery truck and follow Al to the airport, where they enter the baggage handling system and find the suitcase. Stinky Pete rips Woody's arm during a struggle, but Andy's toys stuff him into a little girl's backpack. They free Bullseye, only for Jessie to end up on the plane bound for Japan. Assisted by Buzz and Bullseye, Woody frees Jessie, and the toys find their way home.\r\nWhen Andy returns from camp, he accepts Jessie, Bullseye, and the Aliens as his new toys, thinking that his mother bought them and repairs Woody's torn arm. Al's business has suffered due to him failing to sell the Roundup gang, while Wheezy's squeaker has also been fixed. Woody tells Buzz that he is no longer worried about Andy outgrowing him because, when he eventually does, they will still have each other for company.

# %%
search_similar_movies('dinosaur')
# Out:
#    Relevance                     Movie Title  \
# 0      64.81  We're Back! A Dinosaur's Story
# 1      61.93                    Theodore Rex
# 2      57.93                  The Lost World
# 3      50.03     Carnosaur 3: Primal Species
# 4      47.22                     Dinosaurus!
# 5      46.46                   Jurassic Park
# 6      44.43   The Lost World: Jurassic Park
# 7      42.65                        Dinosaur
# 8      39.28                      Future War
# 9      38.91                  Jurassic World
#
#                                           Movie Plot
# 0  In present-day New York City, an Eastern blueb...
# 1  In an alternate futuristic society where human...
# 2  Professor Challenger (Claude Rains), a famed b...
# 3  In the opening sequence, an army convoy is att...
# 4  The movie is about American men building a har...
# 5  Industrialist John Hammond and his bioengineer...
# 6  On Isla Sorna, an island off the Costa Rican c...
# 7  A Carnotaurus ambushes an infant Parasauroloph...
# 8  Future War begins aboard a spaceship undergoin...
# 9  Brothers Zach and Gray Mitchell visit Isla Nub...

# %%
search_similar_movies('dinosaur adventure')
# Out:
#    Relevance                   Movie Title  \
# 0      57.76             Yona Yona Penguin
# 1      56.61            Çalgı Çengi İkimiz
# 2      48.76                     Green Ice
# 3      48.07               Madanakamarajan
# 4      47.12             Frenchman's Creek
# 5      45.58         The Perils of Pauline
# 6      44.39            The Flying Machine
# 7      44.39            The Flying Machine
# 8      42.43           Women Aren't Angels
# 9      38.38  The Thousand Faces of Dunjia
#
#                                           Movie Plot
# 0  An animated adventure about three children who...
# 1  Two musicians, Salih and Gürkan, described the...
# 2  A down on his luck engineer gets involved in a...
# 3  Madanakamarajan is tale of the adventures of a...
# 4  Set in 17th century London, Joan Fontaine star...
# 5  The premise of the story was that Pauline's we...
# 6  A family takes a journey across the globe on a...
# 7  A family takes a journey across the globe on a...
# 8  Music publishers Wilmer Popday and Alfred Band...
# 9  The film follows a group of swordsmen's advent...

# %%
search_similar_movies('dinosaur park')
# Out:
#    Relevance                     Movie Title  \
# 0      64.05                   Jurassic Park
# 1      52.90                  Jurassic World
# 2      48.10                      A Hard Day
# 3      46.34                     One Got Fat
# 4      43.09              Black Dogs Barking
# 5      43.03  We're Back! A Dinosaur's Story
# 6      41.73   The Lost World: Jurassic Park
# 7      40.39                    Theodore Rex
# 8      38.09                   Rollercoaster
# 9      38.05           The Heart of New York
#
#                                           Movie Plot
# 0  Industrialist John Hammond and his bioengineer...
# 1  Brothers Zach and Gray Mitchell visit Isla Nub...
# 2  Ko, a corrupt detective whose mother recently ...
# 3  In the film, ten children, nine of whom have m...
# 4  Selim’s family has migrated from Anatolia to İ...
# 5  In present-day New York City, an Eastern blueb...
# 6  On Isla Sorna, an island off the Costa Rican c...
# 7  In an alternate futuristic society where human...
# 8  An unnamed man (Timothy Bottoms) (simply calle...
# 9  The plumber Mendel Marantz, a passionate inven...
